# %% [markdown]
# # FORTUNE INDIA COMPANIES RANKING

# %% [markdown]
# The Fortune India 500 is a ranking of the top 500 corporations in India compiled on the basis of latest sales and gross revenue figures. The list is published annually by Fortune magazine

# %% [markdown]
# For more details:
# https://realpython.com/beautiful-soup-web-scraper-python/ on webscraping

# %%
import requests 
from bs4 import BeautifulSoup 
import csv

# %%
print('The following are the details to be extracted\n1.Top 500 Companies & their details\n2.Company Revenue Details\n3.Company History')
# Out:
# The following are the details to be extracted
# 1.Top 500 Companies & their details
# 2.Company Revenue Details
# 3.Company History

# %%
year=int(input("Enter the year"))
URL = "https://www.fortuneindia.com/fortune-500/company-list/reliance-industries?year=%s"%(year)
print(URL)
r = requests.get(URL) 
r
# Out:
# Enter the year2018
# https://www.fortuneindia.com/fortune-500/company-list/reliance-industries?year=2018
# <Response [200]>

# %%
soup = BeautifulSoup(r.content, 'html5lib') 
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <meta content="Reliance Industries - Fortune 500 List 2018 - Fortune India" name="title"/>
# <meta content="Reliance Industries - Get the 2018 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com" itemprop="description" name="description"/>
# <meta content="https://images.assettype.com/fortuneindia/2018-12/35c9485e-3dd4-4147-82d0-d824866b66b0/500_for_web.png" name="image"/>
# <meta content="Reliance Industries - Fortune 500 List 2018 - Fortune India" property="og:title"/>
# <meta content="Reliance Industries - Get the 2018 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com" property="og:description"/>
# <meta content="https://images.assettype.com/fortuneindia/2018-12/35c9485e-3dd4-4147-82d0-d824866b66b0/500_for_web.png" property="og:image"/>
# <meta content="Reliance Industries - Fortune 500 List 2018 - Fortune India" name="twitter:title"/>
# <meta content="Reliance Industries - Get the 2018 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com" name="twitter:description"/>
# <meta content="https://images.assettype.com/fortuneindia/2018-12/35c9485e-3dd4-4147-82d0-d824866b66b0/500_for_web.png" name="twitter:image"/>
# <title>Reliance Industries - Fortune 500 List 2018 - Fortune India</title>
#
#     <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#     <meta charset="utf-8"/>
#
#
#                   <meta content="noindex" name="robots"/>
#               <link href="/manifest.json" rel="manifest"/>
#             <!-- Favicon icon starts -->
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-57x57-d132f1c328.png" rel="apple-touch-icon" sizes="57x57"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-60x60-9bfa66773e.png" rel="apple-touch-icon" sizes="60x60"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-72x72-9c75cae987.png" rel="apple-touch-icon" sizes="72x72"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-76x76-15f014ee3e.png" rel="apple-touch-icon" sizes="76x76"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-114x114-e312f524d0.png" rel="apple-touch-icon" sizes="114x114"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-120x120-163decd241.png" rel="apple-touch-icon" sizes="120x120"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-144x144-d115a2d89c.png" rel="apple-touch-icon" sizes="144x144"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-152x152-084a96997f.png" rel="apple-touch-icon" sizes="152x152"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-180x180-460106316a.png" rel="apple-touch-icon" sizes="180x180"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/android-icon-192x192-f98f331cd2.png" rel="icon" sizes="192x192" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-32x32-b20f1e0ebb.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-96x96-6434980bfe.png" rel="icon" sizes="96x96" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-16x16-4cc07303f8.png" rel="icon" sizes="16x16" type="image/png"/>
#       <!-- Favicon icon Ends -->
#     <link href="https://fea.assettype.com/abp/assets/application-952d47a737.css" rel="stylesheet" type="text/css"/>
#     <link href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,500,600,700,700i,900|Open+Sans:400,600,700,800" rel="stylesheet"/>
#     <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
#
#               <!-- Google Tag Manager -->
#       <script>
#           (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#               '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-TVDVWK');
#       </script>
#       <!-- End Google Tag Manager -->
#
#         <script>
#       var googletag = googletag || {};
#       googletag.cmd = googletag.cmd || [];
#
#       googletag.cmd.push(function () {
#
#         var mapping1 = googletag.sizeMapping().
#             addSize([1, 1 ], [[320, 50], [320,100], [300,250]]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping2 = googletag.sizeMapping().
#             addSize([1, 1 ], [300, 250]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping3 = googletag.sizeMapping().
#             addSize([1, 1 ], [1, 1]). // Mobile
#             addSize([780, 200 ], []).
#             build();
#
#         var mapping4 = googletag.sizeMapping().
#             addSize([780, 200 ], [[728, 90], [970,90]]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping5 = googletag.sizeMapping().
#             addSize([780, 200 ], [[300, 250], [250,250], [336,280]]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping6 = googletag.sizeMapping().
#             addSize([780, 200 ], [1, 1]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping7 = googletag.sizeMapping().
#         		addSize([810, 200 ], ['fluid']). // Desktop
#         		addSize([0, 0 ], []).
#         		build();
#
#         var mapping8 = googletag.sizeMapping().
#             addSize([1, 1 ], [300, 100]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping9 = googletag.sizeMapping().
#                     addSize([780, 200 ], [1140, 200]). // Desktop
#                     addSize([0, 0 ], []).
#                     build();
#
#         var mapping10 = googletag.sizeMapping().
#             addSize([900,90], [970, 250]).
#             addSize([0, 0], [320, 100]).
#             build();
#
#         var mapping11 = googletag.sizeMapping().
#             addSize([900,90], [728, 90]).
#             addSize([0, 0], [300, 250]).
#             build();
#
#         var mapping12 = googletag.sizeMapping().
#             addSize([900,90], [728, 90]).
#             addSize([0, 0], [320, 50]).
#             build();
#
#         var REFRESH_KEY = 'refresh';
#         var REFRESH_VALUE = 'true';
#
#                                           googletag.defineSlot('/1009127/FortuneIndia_Top', [728, 90], 'div-gpt-ad-1501150058174-0').defineSizeMapping(mapping4).addService(googletag.pubads()); // Section Header
#         googletag.defineSlot('/1009127/FortuneIndia_Top', [[300, 100], [320, 50], [300, 250]], 'div-gpt-ad-1501150058174-5').defineSizeMapping(mapping1).addService(googletag.pubads()); // Section Mobile Header
#         googletag.defineSlot('/1009127/FortuneIndia_Bottom', [[728, 90], [320, 50]], 'div-gpt-ad-1501150058178-9').defineSizeMapping(mapping12).addService(googletag.pubads()) // Section Footer Mobile
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_1', [300, 250], 'div-gpt-ad-1501150058174-2').defineSizeMapping(mapping5).addService(googletag.pubads()); // Section RHS 1
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_1', [300, 250], 'div-gpt-ad-1501150058174-6').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 1 Mobile
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-6-3').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 1 Mobile 2
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-3').defineSizeMapping(mapping5).addService(googletag.pubads()); // Section RHS 2
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-6-2').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 2 Mobile
#         // googletag.defineOutOfPageSlot('/1088475/FT_Desk_1x1', 'div-gpt-ad-1501150058174-4').defineSizeMapping(mapping6).addService(googletag.pubads()); // Out of page Section Slot
#         // googletag.defineOutOfPageSlot('/1088475/FT_Mob_1x1', 'div-gpt-ad-1501150058174-8').defineSizeMapping(mapping3).addService(googletag.pubads()); // Out of page Story Section Mobile
#                         googletag.pubads().setTargeting("Homepage", "Section");
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#           qtReady.push(function () {
#             if (event.slot.getSlotElementId() == "div-gpt-ad-1511508149071-0" && !event.isEmpty) {
#               // Hide most read 2nd story so that ad can overlap it.
#               $('.mostread__ad').css('bottom', 0);
#             }
#           });
#         });
#         googletag.pubads().collapseEmptyDivs();
#         googletag.enableServices();
#       });
#     </script>
#     <!-- Qlitics Snippet -->
#     <script>
#       window.qlitics = window.qlitics || function () {
#         (qlitics.q = qlitics.q || []).push(arguments);
#       };
#       qlitics('init');
#       qlitics('track', 'page-view', {'page-type': 'fortune500'});
#     </script>
#     <script async="" src="/qlitics.js"></script>
#     <!-- End Qlitics Snippet -->
#
#     <!-- google custom search -->
#     <script>
#       (function() {
#         var cx = "008330974280404948002:jwejrnee1kl";
#         var gcse = document.createElement('script');
#         gcse.type = 'text/javascript';
#         gcse.async = true;
#         gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(gcse, s);
#       })();
#     </script>
#
#   </head>
#   <body>
#         <!-- Google Tag Manager -->
#     <noscript>
#       <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TVDVWK" style="display:none;visibility:hidden" width="0">
#       </iframe>
#     </noscript>
#     <!-- End of Google Tag Manager -->
#
#     <script type="text/javascript">var qtReady = qtReady || [];</script>
#     <div class="body-container">
#               <!-- /1088475/Ft_Desk_728x90_Header -->
#         <div class="top-ad-container" id="div-gpt-ad-1501150058174-0">
#           <script>
#             googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-0'); });
#           </script>
#         </div>
#                                   <header>
#   <div class="header">
#     <button class="toggle-main-nav" id="toggle-main-nav">
#       <span></span>
#       <span></span>
#       <span></span>
#       <span></span>
#     </button>
#     <div class="site-logo-container">
#       <a class="site-logo" href="/">FortuneIndia</a>
#     </div>
#     <div class="header-search">
#       <div class="header-search__input-container">
#         <form action="/search" method="get">
#           <input class="header-search__input" id="story-search-input" name="q" placeholder="Search.." type="search"/>
#         </form>
#       </div>
#       <button class="header-search__icon" id="toggle-search-bar">
#         <i class="fa fa-search fa-2x fa-white"></i>
#       </button>
#     </div>
#   </div>
#
#   <div class="toolbar js-toolbar-toggle">
#     <div class="toolbar-inner">
#       <span class="menu-item header-item quick-links">Quick Links :</span>
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/fortune-500?year=2020">Fortune India 500</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/40under40">40 Under 40</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/mpw?year=2020">Most Powerful Women</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/next-500">The Next 500</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/the-covid-19-budget-2021">The Covid-19 Budget 2021</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/covid-19-vaccine-in-india">India's Vaccine Roll-out</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/long-reads">Long Reads</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/opinion">Opinion</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/multimedia">Multimedia</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/multimedia/mpw-2019-in-pictures/103764">Events</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/first-edit">First Edit</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#     </div>
#   </div>
#   <div class="sidenav" id="sidenav">
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/fortune-500?year=2020">Fortune India 500</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/next-500">The Next 500</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/40under40">40 Under 40</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/mpw?year=2020">Most Powerful Women</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor section-underline" href="/allrankings">All Rankings</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/multimedia/mpw-2019-in-pictures/103764">Events</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/macro">Macro</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/enterprise">Enterprise</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/technology">Technology</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/reviews">Reviews</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/venture">Venture</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/investing">Investing</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/multimedia">Multimedia</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/bengaluru-buzz">Bengaluru Buzz</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/bystander">Bystander</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/opinion">Opinion</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/ideas">Ideas</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/long-reads">Long Reads</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/people">People</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/polemicist">Polemicist</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.amazon.in/s/ref=dp_byline_sr_book_1?ie=UTF8&amp;field-author=Business+Media+Pvt+Ltd+%28An+ABP+Group+company%29&amp;search-alias=stripbooks">Buy on Amazon</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="http://shop.yudirect.biz/ABP/FortuneIndia/Fortune.php">Annual Subscription</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#   </div>
# </header>
#                 <main class="layout-content">
#         <div id="container">
#           <script>
#     qtReady.push(function () {
#       app.infiniteScroll.init();
#     })
#     </script>
# <section class="f500-list-container">
#               <h2 class="header-with-underline">
#   <span><span class="related-text-header">FORTUNE</span>INDIA 500</span>
# </h2>
#   <div class="buttons-section">
#     <div class="share-button-outer-container">
#       <div class="share-button-container">
#         <div class="share-btn-popup">
#       <div class="share-button" onclick="showHidePopUp(this);"><center>Share</center></div>
#
#   <div class="pop-up pop">
#     <div class="social-links">
#
#
#   <div class="fa fa-twitter fa-6 social-share">
#     <a class="js-social-share" data-service="twitter" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018" data-social-media-type="twitter" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018&amp;text=" target="_blank" title="Twitter">
#     </a>
#   </div>
#   <div class="fa fa-facebook fa-6 social-share">
#     <a class="js-social-share" data-mobile-iframe="true" data-service="facebook" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018" data-social-media-type="facebook" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018&amp;t=" target="_blank" title="Facebook">
#     </a>
#   </div>
#   <div class="fa fa-linkedin fa-6 social-share">
#     <a class="js-social-share" data-service="linkedin" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018" data-social-media-type="linkedin" href="https://www.linkedin.com/shareArticle?mini=true&amp;url=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018" target="_blank" title="Linkedin">
#     </a>
#   </div>
#   <div class="fa fa-whatsapp fa-6 social-share">
#     <a class="js-social-share" data-service="whatsapp" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018" data-social-media-type="whatsapp" href="whatsapp://send?text=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2018" target="_blank">
#     </a>
#   </div>
# </div>
#   </div>
# </div>
#
# <script>
#   function showHidePopUp(popup) {
#       $(popup).parent().find(".pop-up").toggle();
#   }
#
#   qtReady.push(function () {
#       $(document).click(function (event) {
#           if ($(event.target).closest(".share-btn-popup").length === 0) {
#               $(".pop-up").hide();
#           }
#       });
#   });
#
# </script>
#       </div>
#     </div>
#     <div class="filter-dropdown">
#       <div class="year-dropdown">
#         <label class="select">
#           <select class="filter-year" name="filter-name" onchange="javascript:location.href = '/'+'fortune-500'+'/company-list?year=' + this.value;">
#               <option value="2020">2020</option>
#   <option value="2019">2019</option>
#   <option selected="selected" value="2018">2018</option>
#   <option value="2017">2017</option>
#   <option value="2016">2016</option>
#   <option value="2015">2015</option>
#   <option value="2014">2014</option>
#   <option value="2013">2013</option>
#   <option value="2012">2012</option>
#   <option value="2011">2011</option>
#   <option value="2010">2010</option>
#           </select>
#         </label>
#               </div>
#     </div>
#   </div>
#   <div class="f500-filter-body">
#     <div class="list-left-sction show-on-desktop">
#       <div class="f500-list-filter">
#         <div class="button-section-top">
#           <button class="black-button" id="filter-button-desktop" onclick="toggleDektopFilter()">Filter</button>
#           <button class="black-button" id="search-button-desktop" onclick="toggleDesktopSearch()">Search</button>
#         </div>
#         <div class="list-with-dropdown list-with-dropdown-desktop common-filter" id="filter-dropdown-desktop">
#           <form id="filter-form-desktop">
#           <div class="form-group">
#             <label class="form-label">Sort By</label>
#                         <div class="select_container">
#                                     <select class="filter-dropdown" id="sort-by-dropdown" name="sort-by-dropdown">
#     <option value="sort=current-rank&amp;order=asc">Rank, Ascending</option>
#     <option value="sort=current-rank&amp;order=dsc">Rank, Descending</option>
#     <option value="sort=revenue&amp;order=asc">Revenue, Ascending</option>
#     <option value="sort=revenue&amp;order=dsc">Revenue, Descending</option>
#     <option value="sort=noi&amp;order=asc">Net Operating Income, Ascending</option>
#     <option value="sort=noi&amp;order=dsc">Net Operating Income, Descending</option>
#     <option value="sort=profit&amp;order=asc">Profits, Ascending</option>
#     <option value="sort=profit&amp;order=dsc">Profits, Descending</option>
#     <option value="sort=assets&amp;order=asc">Assets, Ascending</option>
#     <option value="sort=assets&amp;order=dsc">Assets, Descending</option>
#     <option value="sort=networth&amp;order=asc">Net Worth, Ascending</option>
#     <option value="sort=networth&amp;order=dsc">Net Worth, Descending</option>
#     <option value="sort=equity-dividend&amp;order=asc">Equity Dividend, Ascending</option>
#     <option value="sort=equity-dividend&amp;order=dsc">Equity Dividend, Descending</option>
#     <option value="sort=employee-cost&amp;order=asc">Employee Cost, Ascending</option>
#     <option value="sort=employee-cost&amp;order=dsc">Employee Cost, Descending</option>
# </select>                              <i aria-hidden="true" class="fa fa-chevron-down"></i>
#             </div>
#                       </div>
#                       <div class="form-group">
#               <label class="form-label">Filter By</label>
#               <div class="select_container">
#                 <select class="filter-dropdown" id="filter-industry-dropdown" name="filter-industry-dropdown">
#                   <option value="">Industry</option>
#                                       <option value="74162">1985</option>
#                                       <option value="14565">Airline Services</option>
#                                       <option value="48659">Airline services</option>
#                                       <option value="18314">Airlines Services</option>
#                                       <option value="43792">Airport services</option>
#                                       <option value="20614">Asset Management (mfs)</option>
#                                       <option value="74077">Asset management (MFs)</option>
#                                       <option value="41838">Asset management [MFs]</option>
#                                       <option value="14420">Auto</option>
#                                       <option value="14506">Auto Ancillaries</option>
#                                       <option value="23948">Auto ancillaries</option>
#                                       <option value="18134">Automobile Ancillaries</option>
#                                       <option value="18224">Automobiles</option>
#                                       <option value="14423">Banking</option>
#                                       <option value="17985">Banking Services</option>
#                                       <option value="14594">Basic Materials</option>
#                                       <option value="23918">Basic materials</option>
#                                       <option value="19072">Beer &amp; Alcohol</option>
#                                       <option value="24188">Beer &amp; alcohol</option>
#                                       <option value="14695">Beer, Alcohol</option>
#                                       <option value="58845">Beer, alcohol</option>
#                                       <option value="14446">Capital Goods</option>
#                                       <option value="23994">Capital goods</option>
#                                       <option value="14549">Cement</option>
#                                       <option value="41907">Clearing &amp; settlement service</option>
#                                       <option value="17214">Coal</option>
#                                       <option value="17257">Computer Education</option>
#                                       <option value="74288">Consultancy services</option>
#                                       <option value="14624">Consumer Durables</option>
#                                       <option value="23910">Consumer durables</option>
#                                       <option value="19478">Credit Rating</option>
#                                       <option value="41489">Credit rating</option>
#                                       <option value="14509">Diversified</option>
#                                       <option value="73127">Diversified Fin. Services</option>
#                                       <option value="48526">Diversified financial services</option>
#                                       <option value="18028">Drugs &amp; Pharmaceuticals</option>
#                                       <option value="24003">Drugs &amp; pharmaceuticals</option>
#                                       <option value="14525">Drugs, Pharma</option>
#                                       <option value="42673">Drugs, pharma</option>
#                                       <option value="73271">Drugs, pharma</option>
#                                       <option value="74365">E-Commerce</option>
#                                       <option value="19431">E-commerce</option>
#                                       <option value="19350">Educational Services</option>
#                                       <option value="41653">Educational services</option>
#                                       <option value="14752">Engg, Construction</option>
#                                       <option value="24000">Engg, construction</option>
#                                       <option value="18127">Engineering &amp; Construction</option>
#                                       <option value="14494">FMCG</option>
#                                       <option value="58691">Facility management</option>
#                                       <option value="15681">Fert, Agro Chem</option>
#                                       <option value="14522">Fert, Agrochem</option>
#                                       <option value="23906">Fert, agro chem</option>
#                                       <option value="41425">Fert, agrochem</option>
#                                       <option value="18019">Fertilisers &amp; Agro Chemicals</option>
#                                       <option value="24263">Fintech</option>
#                                       <option value="18076">Food &amp; Agri Products</option>
#                                       <option value="23991">Food &amp; agri products</option>
#                                       <option value="14615">Food, Agri Products</option>
#                                       <option value="43655">Food, agri products</option>
#                                       <option value="48719">Foreign exchange dealer</option>
#                                       <option value="14430">Gems &amp; Jewellery</option>
#                                       <option value="41536">Gems &amp; jewellery</option>
#                                       <option value="73944">Gems and jewellery</option>
#                                       <option value="23929">Health insurance</option>
#                                       <option value="14907">Healthcare</option>
#                                       <option value="18445">Healthcare &amp; Hospitals</option>
#                                       <option value="29507">Holding company</option>
#                                       <option value="43747">Hospiltality</option>
#                                       <option value="14987">Hospitality</option>
#                                       <option value="14440">Infotech</option>
#                                       <option value="14634">Infra Development</option>
#                                       <option value="41487">Infra development</option>
#                                       <option value="18148">Infrastructure Development</option>
#                                       <option value="29190">Insurance</option>
#                                       <option value="41510">Investment holding </option>
#                                       <option value="14437">Iron &amp; Steel</option>
#                                       <option value="24208">Iron &amp; steel</option>
#                                       <option value="15319">Leather</option>
#                                       <option value="15134">Lube Oils, Lubricants</option>
#                                       <option value="43875">Lube oil, lubricants</option>
#                                       <option value="41527">Lube oils &amp; lubricants</option>
#                                       <option value="14892">Media</option>
#                                       <option value="19403">Media &amp; Entertainment</option>
#                                       <option value="24073">Media &amp; entertainment</option>
#                                       <option value="14452">Metals &amp; Mining</option>
#                                       <option value="23923">Metals &amp; mining</option>
#                                       <option value="73907">Metals and mining</option>
#                                       <option value="15528">Micro Finance</option>
#                                       <option value="24051">Micro finance</option>
#                                       <option value="74334">Microfinance</option>
#                                       <option value="23957">Money changing</option>
#                                       <option value="14478">NBFC</option>
#                                       <option value="18006">Non-banking Financial Services</option>
#                                       <option value="15143">Offshore Drilling</option>
#                                       <option value="18574">Offshore Drilling Services</option>
#                                       <option value="41429">Offshore drilling</option>
#                                       <option value="14414">Oil &amp; Gas</option>
#                                       <option value="41680">Oil &amp; gas</option>
#                                       <option value="20585">Online Classifieds</option>
#                                       <option value="41874">Online classifieds</option>
#                                       <option value="14850">Packaging</option>
#                                       <option value="15052">Paper</option>
#                                       <option value="74062">Payment solutions</option>
#                                       <option value="15067">Plastic Products</option>
#                                       <option value="24222">Plastic products</option>
#                                       <option value="20682">Port</option>
#                                       <option value="41918">Ports</option>
#                                       <option value="14458">Power</option>
#                                       <option value="14732">Real Estate</option>
#                                       <option value="24140">Real estate</option>
#                                       <option value="15328">Recruitment Consulting</option>
#                                       <option value="41520">Recruitment consulting</option>
#                                       <option value="14725">Retail Trade</option>
#                                       <option value="24256">Retail trade</option>
#                                       <option value="14951">Securities Trading</option>
#                                       <option value="18615">Securities Trading &amp; Broking</option>
#                                       <option value="42001">Securities trading</option>
#                                       <option value="29413">Security services</option>
#                                       <option value="16566">Ship Building</option>
#                                       <option value="43427">Ship building</option>
#                                       <option value="15030">Shipping</option>
#                                       <option value="18245">Shipping Services</option>
#                                       <option value="24217">Small finance bank</option>
#                                       <option value="24491">Stock exchange</option>
#                                       <option value="14741">Storage Batteries</option>
#                                       <option value="41558">Storage batteries</option>
#                                       <option value="14612">Sugar</option>
#                                       <option value="14786">Tea &amp; Coffee</option>
#                                       <option value="24409">Tea &amp; coffee</option>
#                                       <option value="14443">Telecommunication</option>
#                                       <option value="18298">Telecommunication Services</option>
#                                       <option value="41459">Telecommunications</option>
#                                       <option value="16423">Textile &amp; Garments</option>
#                                       <option value="14657">Textiles &amp; Garments</option>
#                                       <option value="23902">Textiles &amp; garments</option>
#                                       <option value="73976">Textiles and garments</option>
#                                       <option value="19714">Tobacco Products</option>
#                                       <option value="41775">Tobacco products</option>
#                                       <option value="19691">Tourism Development</option>
#                                       <option value="19460">Trading</option>
#                                       <option value="14877">Transport Logistics</option>
#                                       <option value="18239">Transport Logistics Services</option>
#                                       <option value="24399">Transport logistics</option>
#                                       <option value="15045">Travel Services</option>
#                                       <option value="14639">Tyres &amp; Tubes</option>
#                                       <option value="24098">Tyres &amp; tubes</option>
#                                       <option value="14605">Wholesale Trade</option>
#                                       <option value="16472">Wholesale Trading</option>
#                                       <option value="41606">Wholesale trade</option>
#                                       <option value="73880">\"Drugs</option>
#                                       <option value="73951">\"Engg</option>
#                                       <option value="74251">\"Food</option>
#                                       <option value="74015">\"Lube oils</option>
#                                   </select>
#                 <i aria-hidden="true" class="fa fa-chevron-down"></i>
#               </div>
#
#               <div class="select_container">
#                 <select class="filter-dropdown" id="filter-city-dropdown" name="filter-city-dropdown">
#                   <option value="">City</option>
#                                       <option value="19740">Agra</option>
#                                       <option value="14483">Ahmedabad</option>
#                                       <option value="19988">Ahmednagar</option>
#                                       <option value="14827">Ajmer</option>
#                                       <option value="20781">Alappuzha</option>
#                                       <option value="14777">Aluva</option>
#                                       <option value="15248">Alwar</option>
#                                       <option value="20688">Ameerpet</option>
#                                       <option value="16567">Amreli</option>
#                                       <option value="18077">Anand</option>
#                                       <option value="20358">Anjar</option>
#                                       <option value="20593">Ankleshwar</option>
#                                       <option value="14625">Aurangabad</option>
#                                       <option value="74487">Baghpat</option>
#                                       <option value="15193">Bahadurgarh</option>
#                                       <option value="20067">Balasore</option>
#                                       <option value="15449">Bangalore</option>
#                                       <option value="16224">Banglore</option>
#                                       <option value="19539">Banswara</option>
#                                       <option value="24133">Baramati</option>
#                                       <option value="14738">Belgaum</option>
#                                       <option value="14431">Bengaluru</option>
#                                       <option value="20808">Bhadrak</option>
#                                       <option value="14996">Bharuch</option>
#                                       <option value="20730">Bhatinda</option>
#                                       <option value="15376">Bhawanimandi</option>
#                                       <option value="15207">Bhilwara</option>
#                                       <option value="43864">Bhiwadi</option>
#                                       <option value="19454">Bhiwani</option>
#                                       <option value="15137">Bhopal</option>
#                                       <option value="19162">Bhub'eswar</option>
#                                       <option value="14842">Bhubaneswar</option>
#                                       <option value="20011">Bhuj</option>
#                                       <option value="19408">Bidar</option>
#                                       <option value="15381">Bijnor</option>
#                                       <option value="14851">Bulandshahr</option>
#                                       <option value="19880">Chandigarh</option>
#                                       <option value="15053">Chandrapur</option>
#                                       <option value="41523">Chengalpattu</option>
#                                       <option value="14542">Chennai</option>
#                                       <option value="20416">Chittoor</option>
#                                       <option value="43793">Cochin</option>
#                                       <option value="15243">Coimbatore</option>
#                                       <option value="41485">Dadra &amp; Nagar Haveli</option>
#                                       <option value="15341">Daman &amp; Diu</option>
#                                       <option value="19248">Dandeli</option>
#                                       <option value="14434">Delhi / NCR</option>
#                                       <option value="41419">Delhi-NCR</option>
#                                       <option value="15567">Delhi/NCR</option>
#                                       <option value="24372">Dewas</option>
#                                       <option value="41534">Dhar</option>
#                                       <option value="19795">Dharmapuri</option>
#                                       <option value="19426">Dhrangadhra</option>
#                                       <option value="15072">Dhule</option>
#                                       <option value="14692">Dibrugarh</option>
#                                       <option value="20858">East Godavari</option>
#                                       <option value="16587">Erode</option>
#                                       <option value="15233">Fort Songadh</option>
#                                       <option value="14925">Gajraula</option>
#                                       <option value="14515">Gandhinagar</option>
#                                       <option value="20075">Gautam Budh Nagar</option>
#                                       <option value="74473">Gir Somnath</option>
#                                       <option value="17478">Goa</option>
#                                       <option value="20889">Gudur</option>
#                                       <option value="20531">Guntur</option>
#                                       <option value="16903">Guwahati</option>
#                                       <option value="41630">Hapur</option>
#                                       <option value="24251">Haridwar</option>
#                                       <option value="14589">Hisar</option>
#                                       <option value="14832">Hissar</option>
#                                       <option value="24327">Hosakote</option>
#                                       <option value="20465">Hoshiarpur</option>
#                                       <option value="14679">Hosur</option>
#                                       <option value="15548">Hubli</option>
#                                       <option value="14584">Hyderabad</option>
#                                       <option value="17344">Indore</option>
#                                       <option value="20019">Irinjalakuda</option>
#                                       <option value="15545">Jaintia Hills</option>
#                                       <option value="14710">Jaipur</option>
#                                       <option value="19438">Jalana</option>
#                                       <option value="43785">Jalandhar</option>
#                                       <option value="14861">Jalgaon</option>
#                                       <option value="15483">Jamnagar</option>
#                                       <option value="58476">Jharsuguda</option>
#                                       <option value="41677">Jigani</option>
#                                       <option value="41736">Jodhpur</option>
#                                       <option value="14735">Junagadh</option>
#                                       <option value="41960">Kakinada</option>
#                                       <option value="43898">Kalol</option>
#                                       <option value="43929">Kancheepuram</option>
#                                       <option value="73883">Kanchipuram</option>
#                                       <option value="14866">Kankroli</option>
#                                       <option value="15093">Kanpur</option>
#                                       <option value="19900">Kapurthala</option>
#                                       <option value="74466">Karamsad</option>
#                                       <option value="20801">Karnal</option>
#                                       <option value="14902">Karur</option>
#                                       <option value="20058">Kelambakkam</option>
#                                       <option value="41492">Khammam</option>
#                                       <option value="20765">Khargone</option>
#                                       <option value="15173">Khatima</option>
#                                       <option value="15023">Kheri</option>
#                                       <option value="14671">Kochi</option>
#                                       <option value="15166">Kolhapur</option>
#                                       <option value="14455">Kolkata</option>
#                                       <option value="14700">Kota</option>
#                                       <option value="24074">Kottayam</option>
#                                       <option value="19257">Kovilpatti</option>
#                                       <option value="15140">Kumbakonam</option>
#                                       <option value="20090">Kurnool</option>
#                                       <option value="43738">Kutbullapur</option>
# ...
#                                       <option value="15109">Rajapalayam</option>
#                                       <option value="20433">Rajgangpur</option>
#                                       <option value="19717">Rajkot</option>
#                                       <option value="41456">Rajpura</option>
#                                       <option value="19132">Rajula</option>
#                                       <option value="19318">Rampur</option>
#                                       <option value="20831">Ranavav</option>
#                                       <option value="19749">Ranchi</option>
#                                       <option value="19610">Ranga Reddy</option>
#                                       <option value="20167">Ranipet</option>
#                                       <option value="14928">Ratnagiri</option>
#                                       <option value="20685">Rewa</option>
#                                       <option value="16104">Rewari</option>
#                                       <option value="15432">Saharanpur</option>
#                                       <option value="20875">Saket</option>
#                                       <option value="41984">Salcette</option>
#                                       <option value="19672">Salem</option>
#                                       <option value="43890">Sandur</option>
#                                       <option value="15104">Sanghera</option>
#                                       <option value="20702">Sangli</option>
#                                       <option value="41940">Sangrur</option>
#                                       <option value="20719">Satna</option>
#                                       <option value="24223">Sattari</option>
#                                       <option value="15037">Secunderabad</option>
#                                       <option value="19371">Shillong</option>
#                                       <option value="15238">Sidhpur</option>
#                                       <option value="20748">Sikandrabad</option>
#                                       <option value="15519">Siltara</option>
#                                       <option value="14658">Silvassa</option>
#                                       <option value="20034">Singhbhum</option>
#                                       <option value="15040">Singrauli</option>
#                                       <option value="15262">Sirohi</option>
#                                       <option value="17313">Sitapur</option>
#                                       <option value="17109">Siwani</option>
#                                       <option value="15253">Solan</option>
#                                       <option value="20805">Solapur</option>
#                                       <option value="20816">Sonepat</option>
#                                       <option value="14847">Srinagar</option>
#                                       <option value="43431">Sriperumbudur</option>
#                                       <option value="15230">Sundargarh</option>
#                                       <option value="20055">Sundergarh</option>
#                                       <option value="15364">Surat</option>
#                                       <option value="14705">Thiru'puram</option>
#                                       <option value="19810">Thiruvananthapuram</option>
#                                       <option value="15123">Thoothukudi</option>
#                                       <option value="14912">Thrissur</option>
#                                       <option value="16628">Tinsukia</option>
#                                       <option value="14874">Tiruchirapalli</option>
#                                       <option value="41417">Tiruchirappalli</option>
#                                       <option value="41943">Tirupathi</option>
#                                       <option value="14978">Tirupati</option>
#                                       <option value="43769">Tirupur</option>
#                                       <option value="19413">Toansa</option>
#                                       <option value="43033">Trivandrum</option>
#                                       <option value="15369">Udaipur</option>
#                                       <option value="15361">Udham Singh Nagar</option>
#                                       <option value="15926">Una</option>
#                                       <option value="14449">Vadodara</option>
#                                       <option value="41657">Vallabh Vidyanagar</option>
#                                       <option value="15398">Valsad</option>
#                                       <option value="14646">Vapi</option>
#                                       <option value="15060">Varanasi</option>
#                                       <option value="41772">Vellore</option>
#                                       <option value="14559">Veraval</option>
#                                       <option value="41477">Visakhapatnam</option>
#                                       <option value="15458">Vishakapatnam</option>
#                                       <option value="18064">Vishakhapatam</option>
#                                       <option value="19566">West Godavari</option>
#                                       <option value="15003">Yamuna Nagar</option>
#                                       <option value="19501">Yavatmal</option>
#                                       <option value="14839">Zuarinagar</option>
#                                   </select>
#                 <i aria-hidden="true" class="fa fa-chevron-down"></i>
#               </div>
#             </div>
#
#     </form>
#               <div class="button-section-bottom">
#             <button class="black-button" onclick="resetAll()">Reset</button>
#             <button class="black-button" onclick="applyFilter()">Apply</button>
#           </div>
#
#   </div>
#
#   <div class="company-search-container company-search-container-mobile" id="company-search-mobile">
#     <div class="popup-header">
#       <span class="filter-header">SEARCH</span>
#       <span class="close-button" onclick="closeModalSearch()">×</span>
#     </div>
#     <div class="search-bar-body">
#       <div class="search-box search-box-mobile">
#     <form action="javascript:applyFilter()" class="search-form" id="search_comp_form_mobile" method="GET">
#         <div class="form-el">
#             <input class="search-text-input" id="company-search-input-mobile" name="search" placeholder="Search Company" type="text"/>
#             <button class="button-holder" onclick="applyFilter();" type="submit">
#                 <i class="fa fa-search"></i>
#             </button>
#         </div>
#     </form>
# </div>
#
#     </div>
#               <div class="button-section-bottom">
#             <button class="black-button" onclick="resetAll()">Reset</button>
#             <button class="black-button" onclick="applyFilter()">Apply</button>
#           </div>
#
#   </div>
#   <script>
#     function resetAll(){
#       $('#filter-industry-dropdown option:eq(0)').prop('selected', 'selected');
#       $('#sort-by-dropdown option:eq(0)').prop('selected', 'selected');
#       $('#filter-city-dropdown option:eq(0)').prop('selected', 'selected');
#     }
#     var currentMode = '';
#     var currentDevice = 'desktop';
#     function changePullDown() {
#       $("#mobile-filter-list").slideToggle();
#     }
#     function openFilter() {
#       $("#filter-dropdown-mobile").show();
#       currentMode = 'filter';
#       currentDevice = 'mobile';
#     }
#     function closeModal() {
#       $("#filter-dropdown-mobile").hide();
#       currentMode = '';
#     }
#     function openSearchMobile() {
#       $("#company-search-mobile").show();
#       currentMode = 'search';
#       currentDevice = 'mobile';
#     }
#     function closeModalSearch() {
#       $("#company-search-mobile").hide();
#       currentMode = '';
#     }
#     function toggleDektopFilter() {
#       $("#search-button-desktop").removeClass("white-button");
#       $("#filter-button-desktop").toggleClass("white-button");
#       $(".common-filter:not('#filter-dropdown-desktop')").hide();
#       if($('#filter-dropdown-desktop').css('display') == 'none')
#       {
#         $("#filter-dropdown-desktop").show();
#       } else {
#         $("#filter-dropdown-desktop").hide();
#         $("#filter-companies-desktop").show();
#       }
#       if($("#filter-button-desktop").hasClass('white-button')) {
#
#         currentMode = 'filter';
#       }
#     }
#     function toggleDesktopSearch() {
#
#       $("#filter-button-desktop").removeClass("white-button");
#       $("#search-button-desktop").toggleClass("white-button");
#       $(".common-filter:not('#search-bar-desktop')").hide();
#       if($('#search-bar-desktop').css('display') == 'none')
#       {
#         $("#search-bar-desktop").show();
#       } else {
#         $("#search-bar-desktop").hide();
#         $("#filter-companies-desktop").show();
#       }
#       if($("#search-button-desktop").hasClass('white-button')) {
#
#         currentMode = 'search';
#       }
#     }
#     function scrollToCompany(companySlug) {
#
#
#         if($("#"+CSS.escape(companySlug)).get(0)){
#         var scrollVar = parseInt($('#'+CSS.escape(companySlug)).offset().top) - $('.header').height() - 60;
#         $('html, body').animate({ scrollTop: scrollVar }, 'slow');
#       } else {
#
#         if(window.location.search) {
#           window.location.href = companySlug + window.location.search;
#         } else {
#           window.location.href = companySlug;
#         }
#       }
#     }
#
#     function applyFilter() {
#
#       if(currentMode == 'search') {
#         var searchParam = "";
#         var currentYear = 2018;
#         if (currentDevice === "desktop") {
#           searchParam = $("#search_comp_form_filter").find('input[name="search"]').val();
#         } else {
#           searchParam = $("#search_comp_form_mobile").find("#company-search-input-mobile").val();
#         }
#
#         if (searchParam.trim().length > 0) {
#             location.href = "/"+"fortune-500"+"/company-list/?mode=search&query="+searchParam+"&year="+currentYear;
#         }
#       }
#
#       if(currentMode == 'filter') {
#         if(currentDevice == 'desktop') {
#           var sortBy = $("#filter-form-desktop #sort-by-dropdown").val();
#           var filterIndustry = $("#filter-form-desktop #filter-industry-dropdown").val();
#           var filterCity = $("#filter-form-desktop #filter-city-dropdown").val();
#         } else if(currentDevice == 'mobile') {
#
#           var sortBy = $("#filter-form-mobile #sort-by-dropdown").val();
#           var filterIndustry = $("#filter-form-mobile #filter-industry-dropdown").val();
#           var filterCity = $("#filter-form-mobile #filter-city-dropdown").val();
#         }
#
#         var currentYear = 2018;
#
#         var url = "/"+"fortune-500"+"/company-list/?mode=filter&year="+currentYear;
#         if(filterCity != '' || filterIndustry != '') {
#           var url = "/"+"fortune-500"+"/company-list/?mode=filter&year="+currentYear;
#           if(filterCity) {
#             url = url + "&city=" + filterCity;
#           }
#
#           if(filterIndustry) {
#             url = url + "&industry=" + filterIndustry;
#           }
#         }
#         if(sortBy) {
#           url = url + "&" + sortBy;
#         }
#
#         location.href = url;
#       }
#     }
#
#     function resetAll() {
#       location.href = "/" + "fortune-500" + "/company-list?year=" + "2018";
#     }
#   </script>
# <!-- /1088475/FT_Desk_1x1 -->
# <div id="div-gpt-ad-1501150058174-4">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-4'); });
# </script>
# </div>
# <!-- /1088475/FT_Mob_1x1 -->
# <div id="div-gpt-ad-1501150058174-8">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-8'); });
# </script>
# </div>      </div>
#     </main>
#     <div class="story-go-to-top" onclick="goUp()">
#       <div class="fa fa-angle-up fa-6"></div>
#     </div>
#
#     <div class="cf"></div>
#
#           <footer class="page-footer">
#   <div class="container">
#     <div class="bottom-stickey show-on-mobile" id="div-gpt-ad-1501150058178-9">
#       <script>
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058178-9'); });
#       </script>
#     </div>
#     <div class="footer-block">
#       <div class="footer-link">
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/contact-us">Contact Us</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/core-values">Vision &amp; Core Values</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/terms-of-use">Terms of Use</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/privacy-policy">Privacy &amp; Cookie Policy</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#
#       </div>
#     </div>
#     <div class="h-row">
#       <hr/>
#     </div>
#     <div class="copyright-bottom">
#       <div class="copyright">
#                 ©2021 Business Media Private Limited. All rights reserved.
#       </div>
#       <div class="quintype-powered">
#         <a href="http://www.quintype.com" rel="nofollow" target="_blank" title="Quintype">Powered by Quintype</a>
#       </div>
#     </div>
#     <div class="cf"></div>
#   </div>
# </footer>
#       </div>
#   <script type="text/javascript">
#     var qtConfig = {
#       "image-cdn": "https://images.assettype.com",
#       "polltype-host": "https://api.polltype.com",
#       "mailchimp-config": {
#         mailchimp_key: "",
#         mailchimp_list_id: "",
#         mailchimp_url: ""
#       },
#     };
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#   <script src="https://fea.assettype.com/abp/assets/application-268343de85.js" type="text/javascript"></script>
#   <script type="text/javascript">
#     app.initQtReady();
#
#     function goUp() {
#       app.storyReadMore.scrollToTop();
#     }
#
#     $(document).ready(function(){
#               window.dataLayer = window.dataLayer || [];
#         window.dataLayer.push({
#           'pageType':'fortune500',
#           'Sectionname':'',
#           'cmsContentId': '',
#           'contentUrl': '',
#           'Title': '',
#           'Alternate Title': '',
#           'authorname': '',
#           'tagname': '',
#           'publishdate': '',
#           'publishtime': ''
#         });
#           });
#   </script>
#
#
#
# </body></html>

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta name="title" content="Reliance Industries - Fortune 500 List 2018 - Fortune India"/>\n<meta itemprop="description" name="description" content="Reliance Industries - Get the 2018 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com"/>\n<meta name="image" content="https://images.assettype.com/fortuneindia/2018-12/35c9485e-3dd4-4147-82d0-d824866b66b0/500_for_web.png"/>\n<meta property="og:title" content="Reliance Industries - Fortune 500 List 2018 - Fortune India"/>\n<meta property="og:description" content="Reliance Industries - Get the 2018 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com"/>\n<meta property="og:image" content="https://images.assettype.com/fortuneindia/2018-12/35c9485e-3dd4-4147-82d0-d824866b66b0/500_for_web.png"/>\n<meta name="twitter:title" content="Reliance Industries - Fortune 500 List 2018 - Fortune India"/>\n<meta name="twitter:description" content="Reliance Industries - Get the 2018 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com"/>\n<meta name="twitter:image" content="https://images.assettype.com/fortuneindia/2018-12/35c9485e-3dd4-4147-82d0-d824866b66b0/500_for_web.png"/>\n<title>Reliance Industries - Fortune 500 List 2018 - Fortune India</title>\n    \n    <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport" />\n    <meta charset="UTF-8" />\n\n    \n                  <meta name="robots" content="noindex">\n              <link rel="manifest" href="/manifest.json">\n            <!-- Favicon icon starts -->\n    <link rel="apple-touch-icon" sizes="57x57" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-57x57-d132f1c328.png">\n    <link rel="apple-touch-icon" sizes="60x60" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-60x60-9bfa66773e.png">\n    <link rel="apple-touch-icon" sizes="72x72" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-72x72-9c75cae987.png">\n    <link rel="apple-touch-icon" sizes="76x76" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-76x76-15f014ee3e.png">\n    <link rel="apple-touch-icon" sizes="114x114" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-114x114-e312f524d0.png">\n    <link rel="apple-touch-icon" sizes="120x120" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-120x120-163decd241.png">\n    <link rel="apple-touch-icon" sizes="144x144" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-144x144-d115a2d89c.png">\n    <link rel="apple-touch-icon" sizes="152x152" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-152x152-084a96997f.png">\n    <link rel="apple-touch-icon" sizes="180x180" href="https://fea.assettype.com/abp/assets/favicons/apple-icon-180x180-460106316a.png">\n    <link rel="icon" type="image/png" sizes="192x192"  href="https://fea.assettype.com/abp/assets/favicons/android-icon-192x192-f98f331cd2.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="https://fea.assettype.com/abp/assets/favicons/favicon-32x32-b20f1e0ebb.png">\n    <link rel="icon" type="image/png" sizes="96x96" href="https://fea.assettype.com/abp/assets/favicons/favicon-96x96-6434980bfe.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="https://fea.assettype.com/abp/assets/favicons/favicon-16x16-4cc07303f8.png">\n      <!-- Favicon icon Ends -->\n    <link rel="stylesheet" type="text/css" href="https://fea.assettype.com/abp/assets/application-952d47a737.css"/>\n    <link href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,500,600,700,700i,900|Open+Sans:400,600,700,800" rel="stylesheet">\n    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>\n    \n              <!-- Google Tag Manager -->\ ...

# %%
answer=input("Do you want to extract Top 500 Compny Details")
if (answer=="yes" or answer=="y"):
    print('yes')
elif (answer=="no" or answer=="n"):
    print('no')
else:
    print('Enter your choice(yes|no)')
# Out:
# Do you want to extract Top 500 Compny Details
# Enter your choice(yes|no)

# %% [markdown]
# # TOP 500 COMPANIES AND THEIR DETAILS

# %%
import numpy as np
import pandas as pd
answer=input("Do you want to extract Top 500 Company Details")
if (answer=="yes" or answer=="y" or answer=="Y"):
    tables = soup.find('ul', attrs = {'id':'filter-companies-desktop'})
    company_names=[]
    company_address=[]

    for i in range(0,len(tables.find_all('a'))):
        company_names.append(tables.find_all('a')[i].text.strip())
        company_address.append(tables.find_all('a')[i].get("href"))
    

    company_user_name=[]
    for i in range(0,len(company_address)):
        company_user_name.append(company_address[i].split('/')[5].split('?')[0])

    comp_type=tables.find_all_next('div', attrs = {'class': 'company-industry'})
    comp_type


    def comp_details(comp,year):
        url1='https://www.fortuneindia.com/fortune-500/company-list/%s?year=%s'%(comp,year)
        r1 = requests.get(url1) 
        soup1 = BeautifulSoup(r1.content, 'html5lib') 
        soup1
        industry=soup1.find('p', attrs = {'class':'industry'}).text.split(':')[1]
        inc_year=soup1.find('p', attrs = {'class':'inc-year'}).text.split(':')[1]
        yield industry,inc_year


    comp_industry=[]
    inc_year=[]
    for i in company_user_name:
        a,b=next(comp_details(i,year))
        comp_industry.append(a)
        inc_year.append(b)
    #print(i)
    Companies=pd.DataFrame(zip(company_names,company_address,np.arange(1,501),comp_industry,inc_year),columns=['Company_Name','Company_Details','Rank','Industry type','Foundation_Year'])
    Companies
    with pd.ExcelWriter(r'C:\Users\Sreeram\Downloads\Fortune500 Companies List.xlsx') as writer:
        Companies.to_excel(writer,sheet_name='Company_Details')
elif (answer=="no" or answer=="n" or answer=="N"):
    tables = soup.find('ul', attrs = {'id':'filter-companies-desktop'})
    company_names=[]
    company_address=[]
    for i in range(0,len(tables.find_all('a'))):
        company_names.append(tables.find_all('a')[i].text.strip())
        company_address.append(tables.find_all('a')[i].get("href"))
    
    company_user_name=[]
    for i in range(0,len(company_address)):
        company_user_name.append(company_address[i].split('/')[5].split('?')[0])

    comp_type=tables.find_all_next('div', attrs = {'class': 'company-industry'})
    comp_type

else:
    print('Enter your choice(yes|no)')
# Out:
# Do you want to extract Top 500 Company DetailsY

# %% [markdown]
# # SELECTING A COMPANY TO OBTAIN THEIR REVENUE DETAILS

# %%
print("Use '-' instead of a space")
com_search=input("Enter a Company/MNC name to get their Revenue details")
com_search1=com_search.lower()

count=0
recent_details=[]
for i in company_user_name:
    if com_search1 in i.lower():
        count+=1
        recent_details.append(i.lower())
        #print(i.lower())

    
def comp_link(year):
    search1=input('Company Name')
    url2="https://www.fortuneindia.com/fortune-500/company-list/%s?year=%s"%(search1,year)
    return search1,url2
print(recent_details)
for i in range(0,len(recent_details)):   
    if ((count>0) & (com_search1!=np.array(recent_details)[i])):
        print('Choose from Any of the Industries')
        com_search1,company_det=comp_link(year)
        print(company_det)
        break
        
    elif ((count==1)&(com_search1==np.array(recent_details)[i])):
        print('All fine')
        company_det="https://www.fortuneindia.com/fortune-500/company-list/%s?year=%s"%(com_search1,year)        
        print(company_det) 

if (count==0):  
    print('Company Name not available.Enter it Again')
    #exit()  
#print(count)
# Out:
# Use '-' instead of a space
# Enter a Company/MNC name to get their Revenue detailsxyz
# []
# Company Name not available.Enter it Again

# %%
company_det
# Out:
# 'https://www.fortuneindia.com/fortune-500/company-list/hindustan-unilever?year=2018'

# %%
import pandas as pd
def comp_details_1(comp,year):
    url1='https://www.fortuneindia.com/fortune-500/company-list/%s?year=%s'%(comp,year)
    r1 = requests.get(url1) 
    soup1 = BeautifulSoup(r1.content, 'html5lib') 
    #soup1
    #soup1.find('div', attrs = {'class':'company-parameters'})
    final=soup1.find('div', attrs = {'id':{comp}})
    total=final.find('div', attrs = {'class':'company-parameters'})
    Column=total.find_all('tr')[0].text.strip().replace("\n", "").replace(" ", "-").split('--------')
    parameters1=[]
    crores1=[]
    change_percent1=[]
    for i in range(0,len(total.find_all_next('tr', attrs = {'class': 'table-body'}))-2):
        parameters1.append(total.find_all_next('tr', attrs = {'class': 'table-body'})[i].text.strip().replace("\n", "").replace(" ", "-").split('--------')[0])
        crores1.append(total.find_all_next('tr', attrs = {'class': 'table-body'})[i].text.strip().replace("\n", "").replace(" ", "-").split('--------')[1])
        change_percent1.append(total.find_all_next('tr', attrs = {'class': 'table-body'})[i].text.strip().replace("\n", "").replace(" ", "-").split('--------')[2])
    
    Comp_Revenue=pd.DataFrame(zip(parameters1,crores1,change_percent1),columns=Column)
    return Comp_Revenue  
Comp_Revenue=comp_details_1(com_search1,year)

# %%
Comp_Revenue
# Out:
#              Parameters Rs.-Crore %-Change
# 0               Revenue  2,168.50    17.88
# 1  Net-Operating-Income  2,133.11    20.65
# 2                Profit     66.44   -25.67
# 3                Assets  1,132.84    16.01
# 4             Net-Worth    667.49    10.50
# 5       Equity-Dividend      0.00     0.00
# 6         Employee-Cost    152.93    24.58

# %% [markdown]
# # FORTUNE 500 COMPANY HISTORY

# %%
url1='https://www.fortuneindia.com/fortune-500/company-list/%s?year=%s'%(com_search1,year)
r1 = requests.get(url1)

# %%
url1
# Out:
# 'https://www.fortuneindia.com/fortune-500/company-list/pennar-industries?year=2019'

# %%
soup1=BeautifulSoup(r1.content, 'html5lib') 
soup1
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <meta content="Pennar Industries - Fortune 500 List 2019 - Fortune India" name="title"/>
# <meta content="Pennar Industries - Get the 2019 Fortune India 500 list. Find the revenue, profit and Other financial information for Pennar Industries on Fortuneindia.com" itemprop="description" name="description"/>
# <meta content="https://fea.assettype.com/abp/assets/500-bbd82aacac.jpg" name="image"/>
# <meta content="Pennar Industries - Fortune 500 List 2019 - Fortune India" property="og:title"/>
# <meta content="Pennar Industries - Get the 2019 Fortune India 500 list. Find the revenue, profit and Other financial information for Pennar Industries on Fortuneindia.com" property="og:description"/>
# <meta content="https://fea.assettype.com/abp/assets/500-bbd82aacac.jpg" property="og:image"/>
# <meta content="Pennar Industries - Fortune 500 List 2019 - Fortune India" name="twitter:title"/>
# <meta content="Pennar Industries - Get the 2019 Fortune India 500 list. Find the revenue, profit and Other financial information for Pennar Industries on Fortuneindia.com" name="twitter:description"/>
# <meta content="https://fea.assettype.com/abp/assets/500-bbd82aacac.jpg" name="twitter:image"/>
# <title>Pennar Industries - Fortune 500 List 2019 - Fortune India</title>
#
#     <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#     <meta charset="utf-8"/>
#
#
#                   <meta content="noindex" name="robots"/>
#               <link href="/manifest.json" rel="manifest"/>
#             <!-- Favicon icon starts -->
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-57x57-d132f1c328.png" rel="apple-touch-icon" sizes="57x57"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-60x60-9bfa66773e.png" rel="apple-touch-icon" sizes="60x60"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-72x72-9c75cae987.png" rel="apple-touch-icon" sizes="72x72"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-76x76-15f014ee3e.png" rel="apple-touch-icon" sizes="76x76"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-114x114-e312f524d0.png" rel="apple-touch-icon" sizes="114x114"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-120x120-163decd241.png" rel="apple-touch-icon" sizes="120x120"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-144x144-d115a2d89c.png" rel="apple-touch-icon" sizes="144x144"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-152x152-084a96997f.png" rel="apple-touch-icon" sizes="152x152"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-180x180-460106316a.png" rel="apple-touch-icon" sizes="180x180"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/android-icon-192x192-f98f331cd2.png" rel="icon" sizes="192x192" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-32x32-b20f1e0ebb.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-96x96-6434980bfe.png" rel="icon" sizes="96x96" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-16x16-4cc07303f8.png" rel="icon" sizes="16x16" type="image/png"/>
#       <!-- Favicon icon Ends -->
#     <link href="https://fea.assettype.com/abp/assets/application-952d47a737.css" rel="stylesheet" type="text/css"/>
#     <link href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,500,600,700,700i,900|Open+Sans:400,600,700,800" rel="stylesheet"/>
#     <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
#
#               <!-- Google Tag Manager -->
#       <script>
#           (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#               '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-TVDVWK');
#       </script>
#       <!-- End Google Tag Manager -->
#
#         <script>
#       var googletag = googletag || {};
#       googletag.cmd = googletag.cmd || [];
#
#       googletag.cmd.push(function () {
#
#         var mapping1 = googletag.sizeMapping().
#             addSize([1, 1 ], [[320, 50], [320,100], [300,250]]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping2 = googletag.sizeMapping().
#             addSize([1, 1 ], [300, 250]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping3 = googletag.sizeMapping().
#             addSize([1, 1 ], [1, 1]). // Mobile
#             addSize([780, 200 ], []).
#             build();
#
#         var mapping4 = googletag.sizeMapping().
#             addSize([780, 200 ], [[728, 90], [970,90]]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping5 = googletag.sizeMapping().
#             addSize([780, 200 ], [[300, 250], [250,250], [336,280]]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping6 = googletag.sizeMapping().
#             addSize([780, 200 ], [1, 1]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping7 = googletag.sizeMapping().
#         		addSize([810, 200 ], ['fluid']). // Desktop
#         		addSize([0, 0 ], []).
#         		build();
#
#         var mapping8 = googletag.sizeMapping().
#             addSize([1, 1 ], [300, 100]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping9 = googletag.sizeMapping().
#                     addSize([780, 200 ], [1140, 200]). // Desktop
#                     addSize([0, 0 ], []).
#                     build();
#
#         var mapping10 = googletag.sizeMapping().
#             addSize([900,90], [970, 250]).
#             addSize([0, 0], [320, 100]).
#             build();
#
#         var mapping11 = googletag.sizeMapping().
#             addSize([900,90], [728, 90]).
#             addSize([0, 0], [300, 250]).
#             build();
#
#         var mapping12 = googletag.sizeMapping().
#             addSize([900,90], [728, 90]).
#             addSize([0, 0], [320, 50]).
#             build();
#
#         var REFRESH_KEY = 'refresh';
#         var REFRESH_VALUE = 'true';
#
#                                           googletag.defineSlot('/1009127/FortuneIndia_Top', [728, 90], 'div-gpt-ad-1501150058174-0').defineSizeMapping(mapping4).addService(googletag.pubads()); // Section Header
#         googletag.defineSlot('/1009127/FortuneIndia_Top', [[300, 100], [320, 50], [300, 250]], 'div-gpt-ad-1501150058174-5').defineSizeMapping(mapping1).addService(googletag.pubads()); // Section Mobile Header
#         googletag.defineSlot('/1009127/FortuneIndia_Bottom', [[728, 90], [320, 50]], 'div-gpt-ad-1501150058178-9').defineSizeMapping(mapping12).addService(googletag.pubads()) // Section Footer Mobile
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_1', [300, 250], 'div-gpt-ad-1501150058174-2').defineSizeMapping(mapping5).addService(googletag.pubads()); // Section RHS 1
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_1', [300, 250], 'div-gpt-ad-1501150058174-6').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 1 Mobile
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-6-3').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 1 Mobile 2
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-3').defineSizeMapping(mapping5).addService(googletag.pubads()); // Section RHS 2
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-6-2').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 2 Mobile
#         // googletag.defineOutOfPageSlot('/1088475/FT_Desk_1x1', 'div-gpt-ad-1501150058174-4').defineSizeMapping(mapping6).addService(googletag.pubads()); // Out of page Section Slot
#         // googletag.defineOutOfPageSlot('/1088475/FT_Mob_1x1', 'div-gpt-ad-1501150058174-8').defineSizeMapping(mapping3).addService(googletag.pubads()); // Out of page Story Section Mobile
#                         googletag.pubads().setTargeting("Homepage", "Section");
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#           qtReady.push(function () {
#             if (event.slot.getSlotElementId() == "div-gpt-ad-1511508149071-0" && !event.isEmpty) {
#               // Hide most read 2nd story so that ad can overlap it.
#               $('.mostread__ad').css('bottom', 0);
#             }
#           });
#         });
#         googletag.pubads().collapseEmptyDivs();
#         googletag.enableServices();
#       });
#     </script>
#     <!-- Qlitics Snippet -->
#     <script>
#       window.qlitics = window.qlitics || function () {
#         (qlitics.q = qlitics.q || []).push(arguments);
#       };
#       qlitics('init');
#       qlitics('track', 'page-view', {'page-type': 'fortune500'});
#     </script>
#     <script async="" src="/qlitics.js"></script>
#     <!-- End Qlitics Snippet -->
#
#     <!-- google custom search -->
#     <script>
#       (function() {
#         var cx = "008330974280404948002:jwejrnee1kl";
#         var gcse = document.createElement('script');
#         gcse.type = 'text/javascript';
#         gcse.async = true;
#         gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(gcse, s);
#       })();
#     </script>
#
#   </head>
#   <body>
#         <!-- Google Tag Manager -->
#     <noscript>
#       <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TVDVWK" style="display:none;visibility:hidden" width="0">
#       </iframe>
#     </noscript>
#     <!-- End of Google Tag Manager -->
#
#     <script type="text/javascript">var qtReady = qtReady || [];</script>
#     <div class="body-container">
#               <!-- /1088475/Ft_Desk_728x90_Header -->
#         <div class="top-ad-container" id="div-gpt-ad-1501150058174-0">
#           <script>
#             googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-0'); });
#           </script>
#         </div>
#                                   <header>
#   <div class="header">
#     <button class="toggle-main-nav" id="toggle-main-nav">
#       <span></span>
#       <span></span>
#       <span></span>
#       <span></span>
#     </button>
#     <div class="site-logo-container">
#       <a class="site-logo" href="/">FortuneIndia</a>
#     </div>
#     <div class="header-search">
#       <div class="header-search__input-container">
#         <form action="/search" method="get">
#           <input class="header-search__input" id="story-search-input" name="q" placeholder="Search.." type="search"/>
#         </form>
#       </div>
#       <button class="header-search__icon" id="toggle-search-bar">
#         <i class="fa fa-search fa-2x fa-white"></i>
#       </button>
#     </div>
#   </div>
#
#   <div class="toolbar js-toolbar-toggle">
#     <div class="toolbar-inner">
#       <span class="menu-item header-item quick-links">Quick Links :</span>
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/fortune-500?year=2020">Fortune India 500</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/40under40">40 Under 40</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/mpw?year=2020">Most Powerful Women</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/next-500">The Next 500</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/the-covid-19-budget-2021">The Covid-19 Budget 2021</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/covid-19-vaccine-in-india">India's Vaccine Roll-out</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/long-reads">Long Reads</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/opinion">Opinion</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/multimedia">Multimedia</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/multimedia/mpw-2019-in-pictures/103764">Events</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/first-edit">First Edit</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#     </div>
#   </div>
#   <div class="sidenav" id="sidenav">
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/fortune-500?year=2020">Fortune India 500</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/next-500">The Next 500</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/40under40">40 Under 40</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/mpw?year=2020">Most Powerful Women</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor section-underline" href="/allrankings">All Rankings</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/multimedia/mpw-2019-in-pictures/103764">Events</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/macro">Macro</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/enterprise">Enterprise</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/technology">Technology</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/reviews">Reviews</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/venture">Venture</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/investing">Investing</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/multimedia">Multimedia</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/bengaluru-buzz">Bengaluru Buzz</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/bystander">Bystander</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/opinion">Opinion</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/ideas">Ideas</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/long-reads">Long Reads</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/people">People</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/polemicist">Polemicist</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.amazon.in/s/ref=dp_byline_sr_book_1?ie=UTF8&amp;field-author=Business+Media+Pvt+Ltd+%28An+ABP+Group+company%29&amp;search-alias=stripbooks">Buy on Amazon</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="http://shop.yudirect.biz/ABP/FortuneIndia/Fortune.php">Annual Subscription</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#   </div>
# </header>
#                 <main class="layout-content">
#         <div id="container">
#           <script>
#     qtReady.push(function () {
#       app.infiniteScroll.init();
#     })
#     </script>
# <section class="f500-list-container">
#               <h2 class="header-with-underline">
#   <span><span class="related-text-header">FORTUNE</span>INDIA 500</span>
# </h2>
#   <div class="buttons-section">
#     <div class="share-button-outer-container">
#       <div class="share-button-container">
#         <div class="share-btn-popup">
#       <div class="share-button" onclick="showHidePopUp(this);"><center>Share</center></div>
#
#   <div class="pop-up pop">
#     <div class="social-links">
#
#
#   <div class="fa fa-twitter fa-6 social-share">
#     <a class="js-social-share" data-service="twitter" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="twitter" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019&amp;text=" target="_blank" title="Twitter">
#     </a>
#   </div>
#   <div class="fa fa-facebook fa-6 social-share">
#     <a class="js-social-share" data-mobile-iframe="true" data-service="facebook" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="facebook" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019&amp;t=" target="_blank" title="Facebook">
#     </a>
#   </div>
#   <div class="fa fa-linkedin fa-6 social-share">
#     <a class="js-social-share" data-service="linkedin" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="linkedin" href="https://www.linkedin.com/shareArticle?mini=true&amp;url=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" target="_blank" title="Linkedin">
#     </a>
#   </div>
#   <div class="fa fa-whatsapp fa-6 social-share">
#     <a class="js-social-share" data-service="whatsapp" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="whatsapp" href="whatsapp://send?text=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" target="_blank">
#     </a>
#   </div>
# </div>
#   </div>
# </div>
#
# <script>
#   function showHidePopUp(popup) {
#       $(popup).parent().find(".pop-up").toggle();
#   }
#
#   qtReady.push(function () {
#       $(document).click(function (event) {
#           if ($(event.target).closest(".share-btn-popup").length === 0) {
#               $(".pop-up").hide();
#           }
#       });
#   });
#
# </script>
#       </div>
#     </div>
#     <div class="filter-dropdown">
#       <div class="year-dropdown">
#         <label class="select">
#           <select class="filter-year" name="filter-name" onchange="javascript:location.href = '/'+'fortune-500'+'/company-list?year=' + this.value;">
#               <option value="2020">2020</option>
#   <option selected="selected" value="2019">2019</option>
#   <option value="2018">2018</option>
#   <option value="2017">2017</option>
#   <option value="2016">2016</option>
#   <option value="2015">2015</option>
#   <option value="2014">2014</option>
#   <option value="2013">2013</option>
#   <option value="2012">2012</option>
#   <option value="2011">2011</option>
#   <option value="2010">2010</option>
#           </select>
#         </label>
#               </div>
#     </div>
#   </div>
#   <div class="f500-filter-body">
#     <div class="list-left-sction show-on-desktop">
#       <div class="f500-list-filter">
#         <div class="button-section-top">
#           <button class="black-button" id="filter-button-desktop" onclick="toggleDektopFilter()">Filter</button>
#           <button class="black-button" id="search-button-desktop" onclick="toggleDesktopSearch()">Search</button>
#         </div>
#         <div class="list-with-dropdown list-with-dropdown-desktop common-filter" id="filter-dropdown-desktop">
#           <form id="filter-form-desktop">
#           <div class="form-group">
#             <label class="form-label">Sort By</label>
#                         <div class="select_container">
#                                     <select class="filter-dropdown" id="sort-by-dropdown" name="sort-by-dropdown">
#     <option value="sort=current-rank&amp;order=asc">Rank, Ascending</option>
#     <option value="sort=current-rank&amp;order=dsc">Rank, Descending</option>
#     <option value="sort=revenue&amp;order=asc">Revenue, Ascending</option>
#     <option value="sort=revenue&amp;order=dsc">Revenue, Descending</option>
#     <option value="sort=noi&amp;order=asc">Net Operating Income, Ascending</option>
#     <option value="sort=noi&amp;order=dsc">Net Operating Income, Descending</option>
#     <option value="sort=profit&amp;order=asc">Profits, Ascending</option>
#     <option value="sort=profit&amp;order=dsc">Profits, Descending</option>
#     <option value="sort=assets&amp;order=asc">Assets, Ascending</option>
#     <option value="sort=assets&amp;order=dsc">Assets, Descending</option>
#     <option value="sort=networth&amp;order=asc">Net Worth, Ascending</option>
#     <option value="sort=networth&amp;order=dsc">Net Worth, Descending</option>
#     <option value="sort=equity-dividend&amp;order=asc">Equity Dividend, Ascending</option>
#     <option value="sort=equity-dividend&amp;order=dsc">Equity Dividend, Descending</option>
#     <option value="sort=employee-cost&amp;order=asc">Employee Cost, Ascending</option>
#     <option value="sort=employee-cost&amp;order=dsc">Employee Cost, Descending</option>
# </select>                              <i aria-hidden="true" class="fa fa-chevron-down"></i>
#             </div>
#                       </div>
#                       <div class="form-group">
#               <label class="form-label">Filter By</label>
#               <div class="select_container">
#                 <select class="filter-dropdown" id="filter-industry-dropdown" name="filter-industry-dropdown">
#                   <option value="">Industry</option>
#                                       <option value="74162">1985</option>
#                                       <option value="14565">Airline Services</option>
#                                       <option value="48659">Airline services</option>
#                                       <option value="18314">Airlines Services</option>
#                                       <option value="43792">Airport services</option>
#                                       <option value="20614">Asset Management (mfs)</option>
#                                       <option value="74077">Asset management (MFs)</option>
#                                       <option value="41838">Asset management [MFs]</option>
#                                       <option value="14420">Auto</option>
#                                       <option value="14506">Auto Ancillaries</option>
#                                       <option value="23948">Auto ancillaries</option>
#                                       <option value="18134">Automobile Ancillaries</option>
#                                       <option value="18224">Automobiles</option>
#                                       <option value="14423">Banking</option>
#                                       <option value="17985">Banking Services</option>
#                                       <option value="14594">Basic Materials</option>
#                                       <option value="23918">Basic materials</option>
#                                       <option value="19072">Beer &amp; Alcohol</option>
#                                       <option value="24188">Beer &amp; alcohol</option>
#                                       <option value="14695">Beer, Alcohol</option>
#                                       <option value="58845">Beer, alcohol</option>
#                                       <option value="14446">Capital Goods</option>
#                                       <option value="23994">Capital goods</option>
#                                       <option value="14549">Cement</option>
#                                       <option value="41907">Clearing &amp; settlement service</option>
#                                       <option value="17214">Coal</option>
#                                       <option value="17257">Computer Education</option>
#                                       <option value="74288">Consultancy services</option>
#                                       <option value="14624">Consumer Durables</option>
#                                       <option value="23910">Consumer durables</option>
#                                       <option value="19478">Credit Rating</option>
#                                       <option value="41489">Credit rating</option>
#                                       <option value="14509">Diversified</option>
#                                       <option value="73127">Diversified Fin. Services</option>
#                                       <option value="48526">Diversified financial services</option>
#                                       <option value="18028">Drugs &amp; Pharmaceuticals</option>
#                                       <option value="24003">Drugs &amp; pharmaceuticals</option>
#                                       <option value="14525">Drugs, Pharma</option>
#                                       <option value="42673">Drugs, pharma</option>
#                                       <option value="73271">Drugs, pharma</option>
#                                       <option value="74365">E-Commerce</option>
#                                       <option value="19431">E-commerce</option>
#                                       <option value="19350">Educational Services</option>
#                                       <option value="41653">Educational services</option>
#                                       <option value="14752">Engg, Construction</option>
#                                       <option value="24000">Engg, construction</option>
#                                       <option value="18127">Engineering &amp; Construction</option>
#                                       <option value="14494">FMCG</option>
#                                       <option value="58691">Facility management</option>
#                                       <option value="15681">Fert, Agro Chem</option>
#                                       <option value="14522">Fert, Agrochem</option>
#                                       <option value="23906">Fert, agro chem</option>
#                                       <option value="41425">Fert, agrochem</option>
#                                       <option value="18019">Fertilisers &amp; Agro Chemicals</option>
#                                       <option value="24263">Fintech</option>
#                                       <option value="18076">Food &amp; Agri Products</option>
#                                       <option value="23991">Food &amp; agri products</option>
#                                       <option value="14615">Food, Agri Products</option>
#                                       <option value="43655">Food, agri products</option>
#                                       <option value="48719">Foreign exchange dealer</option>
#                                       <option value="14430">Gems &amp; Jewellery</option>
#                                       <option value="41536">Gems &amp; jewellery</option>
#                                       <option value="73944">Gems and jewellery</option>
#                                       <option value="23929">Health insurance</option>
#                                       <option value="14907">Healthcare</option>
#                                       <option value="18445">Healthcare &amp; Hospitals</option>
#                                       <option value="29507">Holding company</option>
#                                       <option value="43747">Hospiltality</option>
#                                       <option value="14987">Hospitality</option>
#                                       <option value="14440">Infotech</option>
#                                       <option value="14634">Infra Development</option>
#                                       <option value="41487">Infra development</option>
#                                       <option value="18148">Infrastructure Development</option>
#                                       <option value="29190">Insurance</option>
#                                       <option value="41510">Investment holding </option>
#                                       <option value="14437">Iron &amp; Steel</option>
#                                       <option value="24208">Iron &amp; steel</option>
#                                       <option value="15319">Leather</option>
#                                       <option value="15134">Lube Oils, Lubricants</option>
#                                       <option value="43875">Lube oil, lubricants</option>
#                                       <option value="41527">Lube oils &amp; lubricants</option>
#                                       <option value="14892">Media</option>
#                                       <option value="19403">Media &amp; Entertainment</option>
#                                       <option value="24073">Media &amp; entertainment</option>
#                                       <option value="14452">Metals &amp; Mining</option>
#                                       <option value="23923">Metals &amp; mining</option>
#                                       <option value="73907">Metals and mining</option>
#                                       <option value="15528">Micro Finance</option>
#                                       <option value="24051">Micro finance</option>
#                                       <option value="74334">Microfinance</option>
#                                       <option value="23957">Money changing</option>
#                                       <option value="14478">NBFC</option>
#                                       <option value="18006">Non-banking Financial Services</option>
#                                       <option value="15143">Offshore Drilling</option>
#                                       <option value="18574">Offshore Drilling Services</option>
#                                       <option value="41429">Offshore drilling</option>
#                                       <option value="14414">Oil &amp; Gas</option>
#                                       <option value="41680">Oil &amp; gas</option>
#                                       <option value="20585">Online Classifieds</option>
#                                       <option value="41874">Online classifieds</option>
#                                       <option value="14850">Packaging</option>
#                                       <option value="15052">Paper</option>
#                                       <option value="74062">Payment solutions</option>
#                                       <option value="15067">Plastic Products</option>
#                                       <option value="24222">Plastic products</option>
#                                       <option value="20682">Port</option>
#                                       <option value="41918">Ports</option>
#                                       <option value="14458">Power</option>
#                                       <option value="14732">Real Estate</option>
#                                       <option value="24140">Real estate</option>
#                                       <option value="15328">Recruitment Consulting</option>
#                                       <option value="41520">Recruitment consulting</option>
#                                       <option value="14725">Retail Trade</option>
#                                       <option value="24256">Retail trade</option>
#                                       <option value="14951">Securities Trading</option>
#                                       <option value="18615">Securities Trading &amp; Broking</option>
#                                       <option value="42001">Securities trading</option>
#                                       <option value="29413">Security services</option>
#                                       <option value="16566">Ship Building</option>
#                                       <option value="43427">Ship building</option>
#                                       <option value="15030">Shipping</option>
#                                       <option value="18245">Shipping Services</option>
#                                       <option value="24217">Small finance bank</option>
#                                       <option value="24491">Stock exchange</option>
#                                       <option value="14741">Storage Batteries</option>
#                                       <option value="41558">Storage batteries</option>
#                                       <option value="14612">Sugar</option>
#                                       <option value="14786">Tea &amp; Coffee</option>
#                                       <option value="24409">Tea &amp; coffee</option>
#                                       <option value="14443">Telecommunication</option>
#                                       <option value="18298">Telecommunication Services</option>
#                                       <option value="41459">Telecommunications</option>
#                                       <option value="16423">Textile &amp; Garments</option>
#                                       <option value="14657">Textiles &amp; Garments</option>
#                                       <option value="23902">Textiles &amp; garments</option>
#                                       <option value="73976">Textiles and garments</option>
#                                       <option value="19714">Tobacco Products</option>
#                                       <option value="41775">Tobacco products</option>
#                                       <option value="19691">Tourism Development</option>
#                                       <option value="19460">Trading</option>
#                                       <option value="14877">Transport Logistics</option>
#                                       <option value="18239">Transport Logistics Services</option>
#                                       <option value="24399">Transport logistics</option>
#                                       <option value="15045">Travel Services</option>
#                                       <option value="14639">Tyres &amp; Tubes</option>
#                                       <option value="24098">Tyres &amp; tubes</option>
#                                       <option value="14605">Wholesale Trade</option>
#                                       <option value="16472">Wholesale Trading</option>
#                                       <option value="41606">Wholesale trade</option>
#                                       <option value="73880">\"Drugs</option>
#                                       <option value="73951">\"Engg</option>
#                                       <option value="74251">\"Food</option>
#                                       <option value="74015">\"Lube oils</option>
#                                   </select>
#                 <i aria-hidden="true" class="fa fa-chevron-down"></i>
#               </div>
#
#               <div class="select_container">
#                 <select class="filter-dropdown" id="filter-city-dropdown" name="filter-city-dropdown">
#                   <option value="">City</option>
#                                       <option value="19740">Agra</option>
#                                       <option value="14483">Ahmedabad</option>
#                                       <option value="19988">Ahmednagar</option>
#                                       <option value="14827">Ajmer</option>
#                                       <option value="20781">Alappuzha</option>
#                                       <option value="14777">Aluva</option>
#                                       <option value="15248">Alwar</option>
#                                       <option value="20688">Ameerpet</option>
#                                       <option value="16567">Amreli</option>
#                                       <option value="18077">Anand</option>
#                                       <option value="20358">Anjar</option>
#                                       <option value="20593">Ankleshwar</option>
#                                       <option value="14625">Aurangabad</option>
#                                       <option value="74487">Baghpat</option>
#                                       <option value="15193">Bahadurgarh</option>
#                                       <option value="20067">Balasore</option>
#                                       <option value="15449">Bangalore</option>
#                                       <option value="16224">Banglore</option>
#                                       <option value="19539">Banswara</option>
#                                       <option value="24133">Baramati</option>
#                                       <option value="14738">Belgaum</option>
#                                       <option value="14431">Bengaluru</option>
#                                       <option value="20808">Bhadrak</option>
#                                       <option value="14996">Bharuch</option>
#                                       <option value="20730">Bhatinda</option>
#                                       <option value="15376">Bhawanimandi</option>
#                                       <option value="15207">Bhilwara</option>
#                                       <option value="43864">Bhiwadi</option>
#                                       <option value="19454">Bhiwani</option>
#                                       <option value="15137">Bhopal</option>
#                                       <option value="19162">Bhub'eswar</option>
#                                       <option value="14842">Bhubaneswar</option>
#                                       <option value="20011">Bhuj</option>
#                                       <option value="19408">Bidar</option>
#                                       <option value="15381">Bijnor</option>
#                                       <option value="14851">Bulandshahr</option>
#                                       <option value="19880">Chandigarh</option>
#                                       <option value="15053">Chandrapur</option>
#                                       <option value="41523">Chengalpattu</option>
#                                       <option value="14542">Chennai</option>
#                                       <option value="20416">Chittoor</option>
#                                       <option value="43793">Cochin</option>
#                                       <option value="15243">Coimbatore</option>
#                                       <option value="41485">Dadra &amp; Nagar Haveli</option>
#                                       <option value="15341">Daman &amp; Diu</option>
#                                       <option value="19248">Dandeli</option>
#                                       <option value="14434">Delhi / NCR</option>
#                                       <option value="41419">Delhi-NCR</option>
#                                       <option value="15567">Delhi/NCR</option>
#                                       <option value="24372">Dewas</option>
#                                       <option value="41534">Dhar</option>
#                                       <option value="19795">Dharmapuri</option>
#                                       <option value="19426">Dhrangadhra</option>
#                                       <option value="15072">Dhule</option>
#                                       <option value="14692">Dibrugarh</option>
#                                       <option value="20858">East Godavari</option>
#                                       <option value="16587">Erode</option>
#                                       <option value="15233">Fort Songadh</option>
#                                       <option value="14925">Gajraula</option>
#                                       <option value="14515">Gandhinagar</option>
#                                       <option value="20075">Gautam Budh Nagar</option>
#                                       <option value="74473">Gir Somnath</option>
#                                       <option value="17478">Goa</option>
#                                       <option value="20889">Gudur</option>
#                                       <option value="20531">Guntur</option>
#                                       <option value="16903">Guwahati</option>
#                                       <option value="41630">Hapur</option>
#                                       <option value="24251">Haridwar</option>
#                                       <option value="14589">Hisar</option>
#                                       <option value="14832">Hissar</option>
#                                       <option value="24327">Hosakote</option>
#                                       <option value="20465">Hoshiarpur</option>
#                                       <option value="14679">Hosur</option>
#                                       <option value="15548">Hubli</option>
#                                       <option value="14584">Hyderabad</option>
#                                       <option value="17344">Indore</option>
#                                       <option value="20019">Irinjalakuda</option>
#                                       <option value="15545">Jaintia Hills</option>
#                                       <option value="14710">Jaipur</option>
#                                       <option value="19438">Jalana</option>
#                                       <option value="43785">Jalandhar</option>
#                                       <option value="14861">Jalgaon</option>
#                                       <option value="15483">Jamnagar</option>
#                                       <option value="58476">Jharsuguda</option>
#                                       <option value="41677">Jigani</option>
#                                       <option value="41736">Jodhpur</option>
#                                       <option value="14735">Junagadh</option>
#                                       <option value="41960">Kakinada</option>
#                                       <option value="43898">Kalol</option>
#                                       <option value="43929">Kancheepuram</option>
#                                       <option value="73883">Kanchipuram</option>
#                                       <option value="14866">Kankroli</option>
#                                       <option value="15093">Kanpur</option>
#                                       <option value="19900">Kapurthala</option>
#                                       <option value="74466">Karamsad</option>
#                                       <option value="20801">Karnal</option>
#                                       <option value="14902">Karur</option>
#                                       <option value="20058">Kelambakkam</option>
#                                       <option value="41492">Khammam</option>
#                                       <option value="20765">Khargone</option>
#                                       <option value="15173">Khatima</option>
#                                       <option value="15023">Kheri</option>
#                                       <option value="14671">Kochi</option>
#                                       <option value="15166">Kolhapur</option>
#                                       <option value="14455">Kolkata</option>
#                                       <option value="14700">Kota</option>
#                                       <option value="24074">Kottayam</option>
#                                       <option value="19257">Kovilpatti</option>
#                                       <option value="15140">Kumbakonam</option>
#                                       <option value="20090">Kurnool</option>
#                                       <option value="43738">Kutbullapur</option>
#                                       <option value="14793">Kutch</option>
#                                       <option value="20710">Lalru</option>
# ...
#                                       <option value="15109">Rajapalayam</option>
#                                       <option value="20433">Rajgangpur</option>
#                                       <option value="19717">Rajkot</option>
#                                       <option value="41456">Rajpura</option>
#                                       <option value="19132">Rajula</option>
#                                       <option value="19318">Rampur</option>
#                                       <option value="20831">Ranavav</option>
#                                       <option value="19749">Ranchi</option>
#                                       <option value="19610">Ranga Reddy</option>
#                                       <option value="20167">Ranipet</option>
#                                       <option value="14928">Ratnagiri</option>
#                                       <option value="20685">Rewa</option>
#                                       <option value="16104">Rewari</option>
#                                       <option value="15432">Saharanpur</option>
#                                       <option value="20875">Saket</option>
#                                       <option value="41984">Salcette</option>
#                                       <option value="19672">Salem</option>
#                                       <option value="43890">Sandur</option>
#                                       <option value="15104">Sanghera</option>
#                                       <option value="20702">Sangli</option>
#                                       <option value="41940">Sangrur</option>
#                                       <option value="20719">Satna</option>
#                                       <option value="24223">Sattari</option>
#                                       <option value="15037">Secunderabad</option>
#                                       <option value="19371">Shillong</option>
#                                       <option value="15238">Sidhpur</option>
#                                       <option value="20748">Sikandrabad</option>
#                                       <option value="15519">Siltara</option>
#                                       <option value="14658">Silvassa</option>
#                                       <option value="20034">Singhbhum</option>
#                                       <option value="15040">Singrauli</option>
#                                       <option value="15262">Sirohi</option>
#                                       <option value="17313">Sitapur</option>
#                                       <option value="17109">Siwani</option>
#                                       <option value="15253">Solan</option>
#                                       <option value="20805">Solapur</option>
#                                       <option value="20816">Sonepat</option>
#                                       <option value="14847">Srinagar</option>
#                                       <option value="43431">Sriperumbudur</option>
#                                       <option value="15230">Sundargarh</option>
#                                       <option value="20055">Sundergarh</option>
#                                       <option value="15364">Surat</option>
#                                       <option value="14705">Thiru'puram</option>
#                                       <option value="19810">Thiruvananthapuram</option>
#                                       <option value="15123">Thoothukudi</option>
#                                       <option value="14912">Thrissur</option>
#                                       <option value="16628">Tinsukia</option>
#                                       <option value="14874">Tiruchirapalli</option>
#                                       <option value="41417">Tiruchirappalli</option>
#                                       <option value="41943">Tirupathi</option>
#                                       <option value="14978">Tirupati</option>
#                                       <option value="43769">Tirupur</option>
#                                       <option value="19413">Toansa</option>
#                                       <option value="43033">Trivandrum</option>
#                                       <option value="15369">Udaipur</option>
#                                       <option value="15361">Udham Singh Nagar</option>
#                                       <option value="15926">Una</option>
#                                       <option value="14449">Vadodara</option>
#                                       <option value="41657">Vallabh Vidyanagar</option>
#                                       <option value="15398">Valsad</option>
#                                       <option value="14646">Vapi</option>
#                                       <option value="15060">Varanasi</option>
#                                       <option value="41772">Vellore</option>
#                                       <option value="14559">Veraval</option>
#                                       <option value="41477">Visakhapatnam</option>
#                                       <option value="15458">Vishakapatnam</option>
#                                       <option value="18064">Vishakhapatam</option>
#                                       <option value="19566">West Godavari</option>
#                                       <option value="15003">Yamuna Nagar</option>
#                                       <option value="19501">Yavatmal</option>
#                                       <option value="14839">Zuarinagar</option>
#                                   </select>
#                 <i aria-hidden="true" class="fa fa-chevron-down"></i>
#               </div>
#             </div>
#
#     </form>
#               <div class="button-section-bottom">
#             <button class="black-button" onclick="resetAll()">Reset</button>
#             <button class="black-button" onclick="applyFilter()">Apply</button>
#           </div>
#
#   </div>
#
#   <div class="company-search-container company-search-container-mobile" id="company-search-mobile">
#     <div class="popup-header">
#       <span class="filter-header">SEARCH</span>
#       <span class="close-button" onclick="closeModalSearch()">×</span>
#     </div>
#     <div class="search-bar-body">
#       <div class="search-box search-box-mobile">
#     <form action="javascript:applyFilter()" class="search-form" id="search_comp_form_mobile" method="GET">
#         <div class="form-el">
#             <input class="search-text-input" id="company-search-input-mobile" name="search" placeholder="Search Company" type="text"/>
#             <button class="button-holder" onclick="applyFilter();" type="submit">
#                 <i class="fa fa-search"></i>
#             </button>
#         </div>
#     </form>
# </div>
#
#     </div>
#               <div class="button-section-bottom">
#             <button class="black-button" onclick="resetAll()">Reset</button>
#             <button class="black-button" onclick="applyFilter()">Apply</button>
#           </div>
#
#   </div>
#   <script>
#     function resetAll(){
#       $('#filter-industry-dropdown option:eq(0)').prop('selected', 'selected');
#       $('#sort-by-dropdown option:eq(0)').prop('selected', 'selected');
#       $('#filter-city-dropdown option:eq(0)').prop('selected', 'selected');
#     }
#     var currentMode = '';
#     var currentDevice = 'desktop';
#     function changePullDown() {
#       $("#mobile-filter-list").slideToggle();
#     }
#     function openFilter() {
#       $("#filter-dropdown-mobile").show();
#       currentMode = 'filter';
#       currentDevice = 'mobile';
#     }
#     function closeModal() {
#       $("#filter-dropdown-mobile").hide();
#       currentMode = '';
#     }
#     function openSearchMobile() {
#       $("#company-search-mobile").show();
#       currentMode = 'search';
#       currentDevice = 'mobile';
#     }
#     function closeModalSearch() {
#       $("#company-search-mobile").hide();
#       currentMode = '';
#     }
#     function toggleDektopFilter() {
#       $("#search-button-desktop").removeClass("white-button");
#       $("#filter-button-desktop").toggleClass("white-button");
#       $(".common-filter:not('#filter-dropdown-desktop')").hide();
#       if($('#filter-dropdown-desktop').css('display') == 'none')
#       {
#         $("#filter-dropdown-desktop").show();
#       } else {
#         $("#filter-dropdown-desktop").hide();
#         $("#filter-companies-desktop").show();
#       }
#       if($("#filter-button-desktop").hasClass('white-button')) {
#
#         currentMode = 'filter';
#       }
#     }
#     function toggleDesktopSearch() {
#
#       $("#filter-button-desktop").removeClass("white-button");
#       $("#search-button-desktop").toggleClass("white-button");
#       $(".common-filter:not('#search-bar-desktop')").hide();
#       if($('#search-bar-desktop').css('display') == 'none')
#       {
#         $("#search-bar-desktop").show();
#       } else {
#         $("#search-bar-desktop").hide();
#         $("#filter-companies-desktop").show();
#       }
#       if($("#search-button-desktop").hasClass('white-button')) {
#
#         currentMode = 'search';
#       }
#     }
#     function scrollToCompany(companySlug) {
#
#
#         if($("#"+CSS.escape(companySlug)).get(0)){
#         var scrollVar = parseInt($('#'+CSS.escape(companySlug)).offset().top) - $('.header').height() - 60;
#         $('html, body').animate({ scrollTop: scrollVar }, 'slow');
#       } else {
#
#         if(window.location.search) {
#           window.location.href = companySlug + window.location.search;
#         } else {
#           window.location.href = companySlug;
#         }
#       }
#     }
#
#     function applyFilter() {
#
#       if(currentMode == 'search') {
#         var searchParam = "";
#         var currentYear = 2019;
#         if (currentDevice === "desktop") {
#           searchParam = $("#search_comp_form_filter").find('input[name="search"]').val();
#         } else {
#           searchParam = $("#search_comp_form_mobile").find("#company-search-input-mobile").val();
#         }
#
#         if (searchParam.trim().length > 0) {
#             location.href = "/"+"fortune-500"+"/company-list/?mode=search&query="+searchParam+"&year="+currentYear;
#         }
#       }
#
#       if(currentMode == 'filter') {
#         if(currentDevice == 'desktop') {
#           var sortBy = $("#filter-form-desktop #sort-by-dropdown").val();
#           var filterIndustry = $("#filter-form-desktop #filter-industry-dropdown").val();
#           var filterCity = $("#filter-form-desktop #filter-city-dropdown").val();
#         } else if(currentDevice == 'mobile') {
#
#           var sortBy = $("#filter-form-mobile #sort-by-dropdown").val();
#           var filterIndustry = $("#filter-form-mobile #filter-industry-dropdown").val();
#           var filterCity = $("#filter-form-mobile #filter-city-dropdown").val();
#         }
#
#         var currentYear = 2019;
#
#         var url = "/"+"fortune-500"+"/company-list/?mode=filter&year="+currentYear;
#         if(filterCity != '' || filterIndustry != '') {
#           var url = "/"+"fortune-500"+"/company-list/?mode=filter&year="+currentYear;
#           if(filterCity) {
#             url = url + "&city=" + filterCity;
#           }
#
#           if(filterIndustry) {
#             url = url + "&industry=" + filterIndustry;
#           }
#         }
#         if(sortBy) {
#           url = url + "&" + sortBy;
#         }
#
#         location.href = url;
#       }
#     }
#
#     function resetAll() {
#       location.href = "/" + "fortune-500" + "/company-list?year=" + "2019";
#     }
#   </script>
# <!-- /1088475/FT_Desk_1x1 -->
# <div id="div-gpt-ad-1501150058174-4">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-4'); });
# </script>
# </div>
# <!-- /1088475/FT_Mob_1x1 -->
# <div id="div-gpt-ad-1501150058174-8">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-8'); });
# </script>
# </div>      </div>
#     </main>
#     <div class="story-go-to-top" onclick="goUp()">
#       <div class="fa fa-angle-up fa-6"></div>
#     </div>
#
#     <div class="cf"></div>
#
#           <footer class="page-footer">
#   <div class="container">
#     <div class="bottom-stickey show-on-mobile" id="div-gpt-ad-1501150058178-9">
#       <script>
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058178-9'); });
#       </script>
#     </div>
#     <div class="footer-block">
#       <div class="footer-link">
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/contact-us">Contact Us</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/core-values">Vision &amp; Core Values</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/terms-of-use">Terms of Use</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/privacy-policy">Privacy &amp; Cookie Policy</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#
#       </div>
#     </div>
#     <div class="h-row">
#       <hr/>
#     </div>
#     <div class="copyright-bottom">
#       <div class="copyright">
#                 ©2021 Business Media Private Limited. All rights reserved.
#       </div>
#       <div class="quintype-powered">
#         <a href="http://www.quintype.com" rel="nofollow" target="_blank" title="Quintype">Powered by Quintype</a>
#       </div>
#     </div>
#     <div class="cf"></div>
#   </div>
# </footer>
#       </div>
#   <script type="text/javascript">
#     var qtConfig = {
#       "image-cdn": "https://images.assettype.com",
#       "polltype-host": "https://api.polltype.com",
#       "mailchimp-config": {
#         mailchimp_key: "",
#         mailchimp_list_id: "",
#         mailchimp_url: ""
#       },
#     };
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#   <script src="https://fea.assettype.com/abp/assets/application-268343de85.js" type="text/javascript"></script>
#   <script type="text/javascript">
#     app.initQtReady();
#
#     function goUp() {
#       app.storyReadMore.scrollToTop();
#     }
#
#     $(document).ready(function(){
#               window.dataLayer = window.dataLayer || [];
#         window.dataLayer.push({
#           'pageType':'fortune500',
#           'Sectionname':'',
#           'cmsContentId': '',
#           'contentUrl': '',
#           'Title': '',
#           'Alternate Title': '',
#           'authorname': '',
#           'tagname': '',
#           'publishdate': '',
#           'publishtime': ''
#         });
#           });
#   </script>
#
#
#
# </body></html>

# %%
rank=soup1.select_one('script:contains("rank")').text.split(';')[1].split('                    ')[1].split()[2][1:231]

# %%
revenue=soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[2].split()[2][1:319]

# %%
net_operating_revenue=soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[3].split()[2][1:319]

# %%
profit=soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[4].split()[2][1:308]

# %%
assests=soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[5].split()[2][1:316]

# %%
net_worth=soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[6].split()[2][1:316]

# %%
equity_dividend=soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[7].split()[2][1:273]

# %%
employee_cost=soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[8].split()[2][1:299]

# %% [raw]
# re.findall(r"[-+]?\d*\.\d+|\d+",object name)-Regular Expression method to extract all type of numbers
# re.findall(r"[-+]?\d*\.\d+",object name)-Regular expression method to extract only Float integers

# %%
year1=np.array(re.findall(r"\d{4}",employee_cost), dtype=np.int32).min()

# %%
int(year)
# Out:
# 2019

# %%
from datetime import datetime,date
def value_extraction(pattern,year):
    length=datetime.today().year-year
    print(length)
    values=re.findall(r"[-+]?\d*\.\d+",pattern)
    #print(values)
    if len(values)==length:
        #print('1')
        return values
    else:
        #print('2')
        ss=abs(len(values)-length)
        org_value=tuple(values)+tuple(np.zeros(ss))
        return org_value

# %%
employee_cost_value=value_extraction(soup1.select_one('script:contains("rank")').text.strip().replace("\n","").split(';')[1].split('                    ')[8].split()[2][1:299],year1)

employee_cost_value
# Out:
# 2
# ['152.93', '161.84']

# %%
assets_value=value_extraction(assests,year1)
assets_value
# Out:
# 2
# ['1132.84', '1213.80']

# %%
net_operating_revenue_value=value_extraction(net_operating_revenue,year1)
net_operating_revenue_value
# Out:
# 2
# ['2133.11', '2106.55']

# %%
revenue_value=value_extraction(revenue,year1)
revenue_value
# Out:
# 2
# ['2168.50', '2138.26']

# %%
profit_value=value_extraction(profit,year1)
profit_value
# Out:
# 2
# ['66.44', '53.05']

# %%
equity_dividend_value=value_extraction(equity_dividend,year1)
equity_dividend_value
# Out:
# 2
# ('0.00', 0.0)

# %%
net_worth_value=value_extraction(employee_cost,year1)
net_worth_value
# Out:
# 2
# ['152.93', '161.84']

# %%
import re
numbers=re.findall(r"\d+",rank)

#print(numbers)

np.array(numbers, dtype=np.float32)

rank_value=[x for x in np.array(numbers, dtype=np.float32) if x<=500]

rank_value
# Out:
# [498.0, 472.0]

# %%
fortune_500_hist=pd.DataFrame(zip(np.arange(2010,2021),rank_value,revenue_value,net_operating_revenue_value,profit_value,assets_value,net_worth_value,equity_dividend_value,employee_cost_value),columns=['Year','Rank','Revenue','Net_Operating_Revenue','Profit','Assets','Networth','Equity Dividend','Employee Cost'])
fortune_500_hist
# Out:
#    Year   Rank  Revenue Net_Operating_Revenue Profit   Assets Networth  \
# 0  2010  498.0  2168.50               2133.11  66.44  1132.84   152.93
# 1  2011  472.0  2138.26               2106.55  53.05  1213.80   161.84
#
#   Equity Dividend Employee Cost
# 0            0.00        152.93
# 1               0        161.84

# %% [markdown]
# # SELECTING A COMPANY TO OBTAIN THEIR PROFIT RATIOS

# %%
def profit_ratios(comp,year):
    url1='https://www.fortuneindia.com/fortune-500/company-list/%s?year=%s'%(comp,year)
    r1 = requests.get(url1) 
    soup1 = BeautifulSoup(r1.content, 'html5lib') 
    #print(soup1)
    table = soup1.find('div', attrs = {'id':{comp}})
    #print(table)
    table_profit=table.find_all_next('div', attrs = {'class': 'profit-ratios'})[0]
    Column_profit=table_profit.find_all_next('tr', attrs = {'class':'table-body'})[0].text.strip().replace("\n", "").replace(" ", "-").split('------')
    profit=table_profit.find_all_next('tr', attrs = {'class':'table-body'})[1].text.strip().replace("\n", "").replace(" ", "-").split('------')
    Profit=pd.DataFrame(profit).transpose()
    Profit.columns=[Column_profit]
    return Profit
prof_ratio=profit_ratios(com_search1,year)

# %%
prof_ratio
# Out:
#   Revenue Assets Net-Worth
# 0    3.06   5.86      9.95

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <meta content="Reliance Industries - Fortune 500 List 2019 - Fortune India" name="title"/>
# <meta content="Reliance Industries - Get the 2019 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com" itemprop="description" name="description"/>
# <meta content="https://fea.assettype.com/abp/assets/500-bbd82aacac.jpg" name="image"/>
# <meta content="Reliance Industries - Fortune 500 List 2019 - Fortune India" property="og:title"/>
# <meta content="Reliance Industries - Get the 2019 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com" property="og:description"/>
# <meta content="https://fea.assettype.com/abp/assets/500-bbd82aacac.jpg" property="og:image"/>
# <meta content="Reliance Industries - Fortune 500 List 2019 - Fortune India" name="twitter:title"/>
# <meta content="Reliance Industries - Get the 2019 Fortune India 500 list. Find the revenue, profit and Other financial information for Reliance Industries on Fortuneindia.com" name="twitter:description"/>
# <meta content="https://fea.assettype.com/abp/assets/500-bbd82aacac.jpg" name="twitter:image"/>
# <title>Reliance Industries - Fortune 500 List 2019 - Fortune India</title>
#
#     <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#     <meta charset="utf-8"/>
#
#
#                   <meta content="noindex" name="robots"/>
#               <link href="/manifest.json" rel="manifest"/>
#             <!-- Favicon icon starts -->
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-57x57-d132f1c328.png" rel="apple-touch-icon" sizes="57x57"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-60x60-9bfa66773e.png" rel="apple-touch-icon" sizes="60x60"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-72x72-9c75cae987.png" rel="apple-touch-icon" sizes="72x72"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-76x76-15f014ee3e.png" rel="apple-touch-icon" sizes="76x76"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-114x114-e312f524d0.png" rel="apple-touch-icon" sizes="114x114"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-120x120-163decd241.png" rel="apple-touch-icon" sizes="120x120"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-144x144-d115a2d89c.png" rel="apple-touch-icon" sizes="144x144"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-152x152-084a96997f.png" rel="apple-touch-icon" sizes="152x152"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/apple-icon-180x180-460106316a.png" rel="apple-touch-icon" sizes="180x180"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/android-icon-192x192-f98f331cd2.png" rel="icon" sizes="192x192" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-32x32-b20f1e0ebb.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-96x96-6434980bfe.png" rel="icon" sizes="96x96" type="image/png"/>
#     <link href="https://fea.assettype.com/abp/assets/favicons/favicon-16x16-4cc07303f8.png" rel="icon" sizes="16x16" type="image/png"/>
#       <!-- Favicon icon Ends -->
#     <link href="https://fea.assettype.com/abp/assets/application-952d47a737.css" rel="stylesheet" type="text/css"/>
#     <link href="https://fonts.googleapis.com/css?family=Lato:300,400,400i,500,600,700,700i,900|Open+Sans:400,600,700,800" rel="stylesheet"/>
#     <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
#
#               <!-- Google Tag Manager -->
#       <script>
#           (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#               j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#               '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-TVDVWK');
#       </script>
#       <!-- End Google Tag Manager -->
#
#         <script>
#       var googletag = googletag || {};
#       googletag.cmd = googletag.cmd || [];
#
#       googletag.cmd.push(function () {
#
#         var mapping1 = googletag.sizeMapping().
#             addSize([1, 1 ], [[320, 50], [320,100], [300,250]]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping2 = googletag.sizeMapping().
#             addSize([1, 1 ], [300, 250]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping3 = googletag.sizeMapping().
#             addSize([1, 1 ], [1, 1]). // Mobile
#             addSize([780, 200 ], []).
#             build();
#
#         var mapping4 = googletag.sizeMapping().
#             addSize([780, 200 ], [[728, 90], [970,90]]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping5 = googletag.sizeMapping().
#             addSize([780, 200 ], [[300, 250], [250,250], [336,280]]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping6 = googletag.sizeMapping().
#             addSize([780, 200 ], [1, 1]). // Desktop
#             addSize([0, 0 ], []).
#             build();
#
#         var mapping7 = googletag.sizeMapping().
#         		addSize([810, 200 ], ['fluid']). // Desktop
#         		addSize([0, 0 ], []).
#         		build();
#
#         var mapping8 = googletag.sizeMapping().
#             addSize([1, 1 ], [300, 100]). // Mobile
#             addSize([810, 200 ], []).
#             addSize([600, 500 ], []).
#             build();
#
#         var mapping9 = googletag.sizeMapping().
#                     addSize([780, 200 ], [1140, 200]). // Desktop
#                     addSize([0, 0 ], []).
#                     build();
#
#         var mapping10 = googletag.sizeMapping().
#             addSize([900,90], [970, 250]).
#             addSize([0, 0], [320, 100]).
#             build();
#
#         var mapping11 = googletag.sizeMapping().
#             addSize([900,90], [728, 90]).
#             addSize([0, 0], [300, 250]).
#             build();
#
#         var mapping12 = googletag.sizeMapping().
#             addSize([900,90], [728, 90]).
#             addSize([0, 0], [320, 50]).
#             build();
#
#         var REFRESH_KEY = 'refresh';
#         var REFRESH_VALUE = 'true';
#
#                                           googletag.defineSlot('/1009127/FortuneIndia_Top', [728, 90], 'div-gpt-ad-1501150058174-0').defineSizeMapping(mapping4).addService(googletag.pubads()); // Section Header
#         googletag.defineSlot('/1009127/FortuneIndia_Top', [[300, 100], [320, 50], [300, 250]], 'div-gpt-ad-1501150058174-5').defineSizeMapping(mapping1).addService(googletag.pubads()); // Section Mobile Header
#         googletag.defineSlot('/1009127/FortuneIndia_Bottom', [[728, 90], [320, 50]], 'div-gpt-ad-1501150058178-9').defineSizeMapping(mapping12).addService(googletag.pubads()) // Section Footer Mobile
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_1', [300, 250], 'div-gpt-ad-1501150058174-2').defineSizeMapping(mapping5).addService(googletag.pubads()); // Section RHS 1
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_1', [300, 250], 'div-gpt-ad-1501150058174-6').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 1 Mobile
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-6-3').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 1 Mobile 2
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-3').defineSizeMapping(mapping5).addService(googletag.pubads()); // Section RHS 2
#         googletag.defineSlot('/1009127/FortuneIndia_RHS_2', [300, 250], 'div-gpt-ad-1501150058174-6-2').defineSizeMapping(mapping2).addService(googletag.pubads()); // Section RHS 2 Mobile
#         // googletag.defineOutOfPageSlot('/1088475/FT_Desk_1x1', 'div-gpt-ad-1501150058174-4').defineSizeMapping(mapping6).addService(googletag.pubads()); // Out of page Section Slot
#         // googletag.defineOutOfPageSlot('/1088475/FT_Mob_1x1', 'div-gpt-ad-1501150058174-8').defineSizeMapping(mapping3).addService(googletag.pubads()); // Out of page Story Section Mobile
#                         googletag.pubads().setTargeting("Homepage", "Section");
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#           qtReady.push(function () {
#             if (event.slot.getSlotElementId() == "div-gpt-ad-1511508149071-0" && !event.isEmpty) {
#               // Hide most read 2nd story so that ad can overlap it.
#               $('.mostread__ad').css('bottom', 0);
#             }
#           });
#         });
#         googletag.pubads().collapseEmptyDivs();
#         googletag.enableServices();
#       });
#     </script>
#     <!-- Qlitics Snippet -->
#     <script>
#       window.qlitics = window.qlitics || function () {
#         (qlitics.q = qlitics.q || []).push(arguments);
#       };
#       qlitics('init');
#       qlitics('track', 'page-view', {'page-type': 'fortune500'});
#     </script>
#     <script async="" src="/qlitics.js"></script>
#     <!-- End Qlitics Snippet -->
#
#     <!-- google custom search -->
#     <script>
#       (function() {
#         var cx = "008330974280404948002:jwejrnee1kl";
#         var gcse = document.createElement('script');
#         gcse.type = 'text/javascript';
#         gcse.async = true;
#         gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(gcse, s);
#       })();
#     </script>
#
#   </head>
#   <body>
#         <!-- Google Tag Manager -->
#     <noscript>
#       <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TVDVWK" style="display:none;visibility:hidden" width="0">
#       </iframe>
#     </noscript>
#     <!-- End of Google Tag Manager -->
#
#     <script type="text/javascript">var qtReady = qtReady || [];</script>
#     <div class="body-container">
#               <!-- /1088475/Ft_Desk_728x90_Header -->
#         <div class="top-ad-container" id="div-gpt-ad-1501150058174-0">
#           <script>
#             googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-0'); });
#           </script>
#         </div>
#                                   <header>
#   <div class="header">
#     <button class="toggle-main-nav" id="toggle-main-nav">
#       <span></span>
#       <span></span>
#       <span></span>
#       <span></span>
#     </button>
#     <div class="site-logo-container">
#       <a class="site-logo" href="/">FortuneIndia</a>
#     </div>
#     <div class="header-search">
#       <div class="header-search__input-container">
#         <form action="/search" method="get">
#           <input class="header-search__input" id="story-search-input" name="q" placeholder="Search.." type="search"/>
#         </form>
#       </div>
#       <button class="header-search__icon" id="toggle-search-bar">
#         <i class="fa fa-search fa-2x fa-white"></i>
#       </button>
#     </div>
#   </div>
#
#   <div class="toolbar js-toolbar-toggle">
#     <div class="toolbar-inner">
#       <span class="menu-item header-item quick-links">Quick Links :</span>
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/fortune-500?year=2020">Fortune India 500</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/40under40">40 Under 40</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/mpw?year=2020">Most Powerful Women</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/next-500">The Next 500</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/the-covid-19-budget-2021">The Covid-19 Budget 2021</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/covid-19-vaccine-in-india">India's Vaccine Roll-out</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/long-reads">Long Reads</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/opinion">Opinion</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/multimedia">Multimedia</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/multimedia/mpw-2019-in-pictures/103764">Events</a>
#     </li>
#               <li class="menu-item header-item">
#       <a class="menu-anchor" href="/first-edit">First Edit</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#     </div>
#   </div>
#   <div class="sidenav" id="sidenav">
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/fortune-500?year=2020">Fortune India 500</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/next-500">The Next 500</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/40under40">40 Under 40</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/mpw?year=2020">Most Powerful Women</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor section-underline" href="/allrankings">All Rankings</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.fortuneindia.com/multimedia/mpw-2019-in-pictures/103764">Events</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/macro">Macro</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/enterprise">Enterprise</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/technology">Technology</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/reviews">Reviews</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/venture">Venture</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/investing">Investing</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/multimedia">Multimedia</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/bengaluru-buzz">Bengaluru Buzz</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/bystander">Bystander</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/opinion">Opinion</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/ideas">Ideas</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/long-reads">Long Reads</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/people">People</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="/polemicist">Polemicist</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="https://www.amazon.in/s/ref=dp_byline_sr_book_1?ie=UTF8&amp;field-author=Business+Media+Pvt+Ltd+%28An+ABP+Group+company%29&amp;search-alias=stripbooks">Buy on Amazon</a>
#     </li>
#               <li class="menu-item hamburger-item">
#       <a class="menu-anchor section-anchor" href="http://shop.yudirect.biz/ABP/FortuneIndia/Fortune.php">Annual Subscription</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#   </div>
# </header>
#                 <main class="layout-content">
#         <div id="container">
#           <script>
#     qtReady.push(function () {
#       app.infiniteScroll.init();
#     })
#     </script>
# <section class="f500-list-container">
#               <h2 class="header-with-underline">
#   <span><span class="related-text-header">FORTUNE</span>INDIA 500</span>
# </h2>
#   <div class="buttons-section">
#     <div class="share-button-outer-container">
#       <div class="share-button-container">
#         <div class="share-btn-popup">
#       <div class="share-button" onclick="showHidePopUp(this);"><center>Share</center></div>
#
#   <div class="pop-up pop">
#     <div class="social-links">
#
#
#   <div class="fa fa-twitter fa-6 social-share">
#     <a class="js-social-share" data-service="twitter" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="twitter" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019&amp;text=" target="_blank" title="Twitter">
#     </a>
#   </div>
#   <div class="fa fa-facebook fa-6 social-share">
#     <a class="js-social-share" data-mobile-iframe="true" data-service="facebook" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="facebook" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019&amp;t=" target="_blank" title="Facebook">
#     </a>
#   </div>
#   <div class="fa fa-linkedin fa-6 social-share">
#     <a class="js-social-share" data-service="linkedin" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="linkedin" href="https://www.linkedin.com/shareArticle?mini=true&amp;url=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" target="_blank" title="Linkedin">
#     </a>
#   </div>
#   <div class="fa fa-whatsapp fa-6 social-share">
#     <a class="js-social-share" data-service="whatsapp" data-social-media-share-url="https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" data-social-media-type="whatsapp" href="whatsapp://send?text=https%3A%2F%2Fwww.fortuneindia.com%2Ffortune-500%2Fcompany-list%3Fyear%3D2019" target="_blank">
#     </a>
#   </div>
# </div>
#   </div>
# </div>
#
# <script>
#   function showHidePopUp(popup) {
#       $(popup).parent().find(".pop-up").toggle();
#   }
#
#   qtReady.push(function () {
#       $(document).click(function (event) {
#           if ($(event.target).closest(".share-btn-popup").length === 0) {
#               $(".pop-up").hide();
#           }
#       });
#   });
#
# </script>
#       </div>
#     </div>
#     <div class="filter-dropdown">
#       <div class="year-dropdown">
#         <label class="select">
#           <select class="filter-year" name="filter-name" onchange="javascript:location.href = '/'+'fortune-500'+'/company-list?year=' + this.value;">
#               <option value="2020">2020</option>
#   <option selected="selected" value="2019">2019</option>
#   <option value="2018">2018</option>
#   <option value="2017">2017</option>
#   <option value="2016">2016</option>
#   <option value="2015">2015</option>
#   <option value="2014">2014</option>
#   <option value="2013">2013</option>
#   <option value="2012">2012</option>
#   <option value="2011">2011</option>
#   <option value="2010">2010</option>
#           </select>
#         </label>
#               </div>
#     </div>
#   </div>
#   <div class="f500-filter-body">
#     <div class="list-left-sction show-on-desktop">
#       <div class="f500-list-filter">
#         <div class="button-section-top">
#           <button class="black-button" id="filter-button-desktop" onclick="toggleDektopFilter()">Filter</button>
#           <button class="black-button" id="search-button-desktop" onclick="toggleDesktopSearch()">Search</button>
#         </div>
#         <div class="list-with-dropdown list-with-dropdown-desktop common-filter" id="filter-dropdown-desktop">
#           <form id="filter-form-desktop">
#           <div class="form-group">
#             <label class="form-label">Sort By</label>
#                         <div class="select_container">
#                                     <select class="filter-dropdown" id="sort-by-dropdown" name="sort-by-dropdown">
#     <option value="sort=current-rank&amp;order=asc">Rank, Ascending</option>
#     <option value="sort=current-rank&amp;order=dsc">Rank, Descending</option>
#     <option value="sort=revenue&amp;order=asc">Revenue, Ascending</option>
#     <option value="sort=revenue&amp;order=dsc">Revenue, Descending</option>
#     <option value="sort=noi&amp;order=asc">Net Operating Income, Ascending</option>
#     <option value="sort=noi&amp;order=dsc">Net Operating Income, Descending</option>
#     <option value="sort=profit&amp;order=asc">Profits, Ascending</option>
#     <option value="sort=profit&amp;order=dsc">Profits, Descending</option>
#     <option value="sort=assets&amp;order=asc">Assets, Ascending</option>
#     <option value="sort=assets&amp;order=dsc">Assets, Descending</option>
#     <option value="sort=networth&amp;order=asc">Net Worth, Ascending</option>
#     <option value="sort=networth&amp;order=dsc">Net Worth, Descending</option>
#     <option value="sort=equity-dividend&amp;order=asc">Equity Dividend, Ascending</option>
#     <option value="sort=equity-dividend&amp;order=dsc">Equity Dividend, Descending</option>
#     <option value="sort=employee-cost&amp;order=asc">Employee Cost, Ascending</option>
#     <option value="sort=employee-cost&amp;order=dsc">Employee Cost, Descending</option>
# </select>                              <i aria-hidden="true" class="fa fa-chevron-down"></i>
#             </div>
#                       </div>
#                       <div class="form-group">
#               <label class="form-label">Filter By</label>
#               <div class="select_container">
#                 <select class="filter-dropdown" id="filter-industry-dropdown" name="filter-industry-dropdown">
#                   <option value="">Industry</option>
#                                       <option value="74162">1985</option>
#                                       <option value="14565">Airline Services</option>
#                                       <option value="48659">Airline services</option>
#                                       <option value="18314">Airlines Services</option>
#                                       <option value="43792">Airport services</option>
#                                       <option value="20614">Asset Management (mfs)</option>
#                                       <option value="74077">Asset management (MFs)</option>
#                                       <option value="41838">Asset management [MFs]</option>
#                                       <option value="14420">Auto</option>
#                                       <option value="14506">Auto Ancillaries</option>
#                                       <option value="23948">Auto ancillaries</option>
#                                       <option value="18134">Automobile Ancillaries</option>
#                                       <option value="18224">Automobiles</option>
#                                       <option value="14423">Banking</option>
#                                       <option value="17985">Banking Services</option>
#                                       <option value="14594">Basic Materials</option>
#                                       <option value="23918">Basic materials</option>
#                                       <option value="19072">Beer &amp; Alcohol</option>
#                                       <option value="24188">Beer &amp; alcohol</option>
#                                       <option value="14695">Beer, Alcohol</option>
#                                       <option value="58845">Beer, alcohol</option>
#                                       <option value="14446">Capital Goods</option>
#                                       <option value="23994">Capital goods</option>
#                                       <option value="14549">Cement</option>
#                                       <option value="41907">Clearing &amp; settlement service</option>
#                                       <option value="17214">Coal</option>
#                                       <option value="17257">Computer Education</option>
#                                       <option value="74288">Consultancy services</option>
#                                       <option value="14624">Consumer Durables</option>
#                                       <option value="23910">Consumer durables</option>
#                                       <option value="19478">Credit Rating</option>
#                                       <option value="41489">Credit rating</option>
#                                       <option value="14509">Diversified</option>
#                                       <option value="73127">Diversified Fin. Services</option>
#                                       <option value="48526">Diversified financial services</option>
#                                       <option value="18028">Drugs &amp; Pharmaceuticals</option>
#                                       <option value="24003">Drugs &amp; pharmaceuticals</option>
#                                       <option value="14525">Drugs, Pharma</option>
#                                       <option value="42673">Drugs, pharma</option>
#                                       <option value="73271">Drugs, pharma</option>
#                                       <option value="74365">E-Commerce</option>
#                                       <option value="19431">E-commerce</option>
#                                       <option value="19350">Educational Services</option>
#                                       <option value="41653">Educational services</option>
#                                       <option value="14752">Engg, Construction</option>
#                                       <option value="24000">Engg, construction</option>
#                                       <option value="18127">Engineering &amp; Construction</option>
#                                       <option value="14494">FMCG</option>
#                                       <option value="58691">Facility management</option>
#                                       <option value="15681">Fert, Agro Chem</option>
#                                       <option value="14522">Fert, Agrochem</option>
#                                       <option value="23906">Fert, agro chem</option>
#                                       <option value="41425">Fert, agrochem</option>
#                                       <option value="18019">Fertilisers &amp; Agro Chemicals</option>
#                                       <option value="24263">Fintech</option>
#                                       <option value="18076">Food &amp; Agri Products</option>
#                                       <option value="23991">Food &amp; agri products</option>
#                                       <option value="14615">Food, Agri Products</option>
#                                       <option value="43655">Food, agri products</option>
#                                       <option value="48719">Foreign exchange dealer</option>
#                                       <option value="14430">Gems &amp; Jewellery</option>
#                                       <option value="41536">Gems &amp; jewellery</option>
#                                       <option value="73944">Gems and jewellery</option>
#                                       <option value="23929">Health insurance</option>
#                                       <option value="14907">Healthcare</option>
#                                       <option value="18445">Healthcare &amp; Hospitals</option>
#                                       <option value="29507">Holding company</option>
#                                       <option value="43747">Hospiltality</option>
#                                       <option value="14987">Hospitality</option>
#                                       <option value="14440">Infotech</option>
#                                       <option value="14634">Infra Development</option>
#                                       <option value="41487">Infra development</option>
#                                       <option value="18148">Infrastructure Development</option>
#                                       <option value="29190">Insurance</option>
#                                       <option value="41510">Investment holding </option>
#                                       <option value="14437">Iron &amp; Steel</option>
#                                       <option value="24208">Iron &amp; steel</option>
#                                       <option value="15319">Leather</option>
#                                       <option value="15134">Lube Oils, Lubricants</option>
#                                       <option value="43875">Lube oil, lubricants</option>
#                                       <option value="41527">Lube oils &amp; lubricants</option>
#                                       <option value="14892">Media</option>
#                                       <option value="19403">Media &amp; Entertainment</option>
#                                       <option value="24073">Media &amp; entertainment</option>
#                                       <option value="14452">Metals &amp; Mining</option>
#                                       <option value="23923">Metals &amp; mining</option>
#                                       <option value="73907">Metals and mining</option>
#                                       <option value="15528">Micro Finance</option>
#                                       <option value="24051">Micro finance</option>
#                                       <option value="74334">Microfinance</option>
#                                       <option value="23957">Money changing</option>
#                                       <option value="14478">NBFC</option>
#                                       <option value="18006">Non-banking Financial Services</option>
#                                       <option value="15143">Offshore Drilling</option>
#                                       <option value="18574">Offshore Drilling Services</option>
#                                       <option value="41429">Offshore drilling</option>
#                                       <option value="14414">Oil &amp; Gas</option>
#                                       <option value="41680">Oil &amp; gas</option>
#                                       <option value="20585">Online Classifieds</option>
#                                       <option value="41874">Online classifieds</option>
#                                       <option value="14850">Packaging</option>
#                                       <option value="15052">Paper</option>
#                                       <option value="74062">Payment solutions</option>
#                                       <option value="15067">Plastic Products</option>
#                                       <option value="24222">Plastic products</option>
#                                       <option value="20682">Port</option>
#                                       <option value="41918">Ports</option>
#                                       <option value="14458">Power</option>
#                                       <option value="14732">Real Estate</option>
#                                       <option value="24140">Real estate</option>
#                                       <option value="15328">Recruitment Consulting</option>
#                                       <option value="41520">Recruitment consulting</option>
#                                       <option value="14725">Retail Trade</option>
#                                       <option value="24256">Retail trade</option>
#                                       <option value="14951">Securities Trading</option>
#                                       <option value="18615">Securities Trading &amp; Broking</option>
#                                       <option value="42001">Securities trading</option>
#                                       <option value="29413">Security services</option>
#                                       <option value="16566">Ship Building</option>
#                                       <option value="43427">Ship building</option>
#                                       <option value="15030">Shipping</option>
#                                       <option value="18245">Shipping Services</option>
#                                       <option value="24217">Small finance bank</option>
#                                       <option value="24491">Stock exchange</option>
#                                       <option value="14741">Storage Batteries</option>
#                                       <option value="41558">Storage batteries</option>
#                                       <option value="14612">Sugar</option>
#                                       <option value="14786">Tea &amp; Coffee</option>
#                                       <option value="24409">Tea &amp; coffee</option>
#                                       <option value="14443">Telecommunication</option>
#                                       <option value="18298">Telecommunication Services</option>
#                                       <option value="41459">Telecommunications</option>
#                                       <option value="16423">Textile &amp; Garments</option>
#                                       <option value="14657">Textiles &amp; Garments</option>
#                                       <option value="23902">Textiles &amp; garments</option>
#                                       <option value="73976">Textiles and garments</option>
#                                       <option value="19714">Tobacco Products</option>
#                                       <option value="41775">Tobacco products</option>
#                                       <option value="19691">Tourism Development</option>
#                                       <option value="19460">Trading</option>
#                                       <option value="14877">Transport Logistics</option>
#                                       <option value="18239">Transport Logistics Services</option>
#                                       <option value="24399">Transport logistics</option>
#                                       <option value="15045">Travel Services</option>
#                                       <option value="14639">Tyres &amp; Tubes</option>
#                                       <option value="24098">Tyres &amp; tubes</option>
#                                       <option value="14605">Wholesale Trade</option>
#                                       <option value="16472">Wholesale Trading</option>
#                                       <option value="41606">Wholesale trade</option>
#                                       <option value="73880">\"Drugs</option>
#                                       <option value="73951">\"Engg</option>
#                                       <option value="74251">\"Food</option>
#                                       <option value="74015">\"Lube oils</option>
#                                   </select>
#                 <i aria-hidden="true" class="fa fa-chevron-down"></i>
#               </div>
#
#               <div class="select_container">
#                 <select class="filter-dropdown" id="filter-city-dropdown" name="filter-city-dropdown">
#                   <option value="">City</option>
#                                       <option value="19740">Agra</option>
#                                       <option value="14483">Ahmedabad</option>
#                                       <option value="19988">Ahmednagar</option>
#                                       <option value="14827">Ajmer</option>
#                                       <option value="20781">Alappuzha</option>
#                                       <option value="14777">Aluva</option>
#                                       <option value="15248">Alwar</option>
#                                       <option value="20688">Ameerpet</option>
#                                       <option value="16567">Amreli</option>
#                                       <option value="18077">Anand</option>
#                                       <option value="20358">Anjar</option>
#                                       <option value="20593">Ankleshwar</option>
#                                       <option value="14625">Aurangabad</option>
#                                       <option value="74487">Baghpat</option>
#                                       <option value="15193">Bahadurgarh</option>
#                                       <option value="20067">Balasore</option>
#                                       <option value="15449">Bangalore</option>
#                                       <option value="16224">Banglore</option>
#                                       <option value="19539">Banswara</option>
#                                       <option value="24133">Baramati</option>
#                                       <option value="14738">Belgaum</option>
#                                       <option value="14431">Bengaluru</option>
#                                       <option value="20808">Bhadrak</option>
#                                       <option value="14996">Bharuch</option>
#                                       <option value="20730">Bhatinda</option>
#                                       <option value="15376">Bhawanimandi</option>
#                                       <option value="15207">Bhilwara</option>
#                                       <option value="43864">Bhiwadi</option>
#                                       <option value="19454">Bhiwani</option>
#                                       <option value="15137">Bhopal</option>
#                                       <option value="19162">Bhub'eswar</option>
#                                       <option value="14842">Bhubaneswar</option>
#                                       <option value="20011">Bhuj</option>
#                                       <option value="19408">Bidar</option>
#                                       <option value="15381">Bijnor</option>
#                                       <option value="14851">Bulandshahr</option>
#                                       <option value="19880">Chandigarh</option>
#                                       <option value="15053">Chandrapur</option>
#                                       <option value="41523">Chengalpattu</option>
#                                       <option value="14542">Chennai</option>
#                                       <option value="20416">Chittoor</option>
#                                       <option value="43793">Cochin</option>
#                                       <option value="15243">Coimbatore</option>
#                                       <option value="41485">Dadra &amp; Nagar Haveli</option>
#                                       <option value="15341">Daman &amp; Diu</option>
#                                       <option value="19248">Dandeli</option>
#                                       <option value="14434">Delhi / NCR</option>
#                                       <option value="41419">Delhi-NCR</option>
#                                       <option value="15567">Delhi/NCR</option>
#                                       <option value="24372">Dewas</option>
#                                       <option value="41534">Dhar</option>
#                                       <option value="19795">Dharmapuri</option>
#                                       <option value="19426">Dhrangadhra</option>
#                                       <option value="15072">Dhule</option>
#                                       <option value="14692">Dibrugarh</option>
#                                       <option value="20858">East Godavari</option>
#                                       <option value="16587">Erode</option>
#                                       <option value="15233">Fort Songadh</option>
#                                       <option value="14925">Gajraula</option>
#                                       <option value="14515">Gandhinagar</option>
#                                       <option value="20075">Gautam Budh Nagar</option>
#                                       <option value="74473">Gir Somnath</option>
#                                       <option value="17478">Goa</option>
#                                       <option value="20889">Gudur</option>
#                                       <option value="20531">Guntur</option>
#                                       <option value="16903">Guwahati</option>
#                                       <option value="41630">Hapur</option>
#                                       <option value="24251">Haridwar</option>
#                                       <option value="14589">Hisar</option>
#                                       <option value="14832">Hissar</option>
#                                       <option value="24327">Hosakote</option>
#                                       <option value="20465">Hoshiarpur</option>
#                                       <option value="14679">Hosur</option>
#                                       <option value="15548">Hubli</option>
#                                       <option value="14584">Hyderabad</option>
#                                       <option value="17344">Indore</option>
#                                       <option value="20019">Irinjalakuda</option>
#                                       <option value="15545">Jaintia Hills</option>
#                                       <option value="14710">Jaipur</option>
#                                       <option value="19438">Jalana</option>
#                                       <option value="43785">Jalandhar</option>
#                                       <option value="14861">Jalgaon</option>
#                                       <option value="15483">Jamnagar</option>
#                                       <option value="58476">Jharsuguda</option>
#                                       <option value="41677">Jigani</option>
#                                       <option value="41736">Jodhpur</option>
#                                       <option value="14735">Junagadh</option>
#                                       <option value="41960">Kakinada</option>
#                                       <option value="43898">Kalol</option>
#                                       <option value="43929">Kancheepuram</option>
#                                       <option value="73883">Kanchipuram</option>
#                                       <option value="14866">Kankroli</option>
#                                       <option value="15093">Kanpur</option>
#                                       <option value="19900">Kapurthala</option>
#                                       <option value="74466">Karamsad</option>
#                                       <option value="20801">Karnal</option>
#                                       <option value="14902">Karur</option>
#                                       <option value="20058">Kelambakkam</option>
#                                       <option value="41492">Khammam</option>
#                                       <option value="20765">Khargone</option>
#                                       <option value="15173">Khatima</option>
#                                       <option value="15023">Kheri</option>
#                                       <option value="14671">Kochi</option>
#                                       <option value="15166">Kolhapur</option>
#                                       <option value="14455">Kolkata</option>
#                                       <option value="14700">Kota</option>
#                                       <option value="24074">Kottayam</option>
#                                       <option value="19257">Kovilpatti</option>
#                                       <option value="15140">Kumbakonam</option>
#                                       <option value="20090">Kurnool</option>
#                                       <option value="43738">Kutbullapur</option>
#                                       <option value="14793">Kutch</option>
#                                       <option value="20710">Lalru</option>
# ...
#                                       <option value="15109">Rajapalayam</option>
#                                       <option value="20433">Rajgangpur</option>
#                                       <option value="19717">Rajkot</option>
#                                       <option value="41456">Rajpura</option>
#                                       <option value="19132">Rajula</option>
#                                       <option value="19318">Rampur</option>
#                                       <option value="20831">Ranavav</option>
#                                       <option value="19749">Ranchi</option>
#                                       <option value="19610">Ranga Reddy</option>
#                                       <option value="20167">Ranipet</option>
#                                       <option value="14928">Ratnagiri</option>
#                                       <option value="20685">Rewa</option>
#                                       <option value="16104">Rewari</option>
#                                       <option value="15432">Saharanpur</option>
#                                       <option value="20875">Saket</option>
#                                       <option value="41984">Salcette</option>
#                                       <option value="19672">Salem</option>
#                                       <option value="43890">Sandur</option>
#                                       <option value="15104">Sanghera</option>
#                                       <option value="20702">Sangli</option>
#                                       <option value="41940">Sangrur</option>
#                                       <option value="20719">Satna</option>
#                                       <option value="24223">Sattari</option>
#                                       <option value="15037">Secunderabad</option>
#                                       <option value="19371">Shillong</option>
#                                       <option value="15238">Sidhpur</option>
#                                       <option value="20748">Sikandrabad</option>
#                                       <option value="15519">Siltara</option>
#                                       <option value="14658">Silvassa</option>
#                                       <option value="20034">Singhbhum</option>
#                                       <option value="15040">Singrauli</option>
#                                       <option value="15262">Sirohi</option>
#                                       <option value="17313">Sitapur</option>
#                                       <option value="17109">Siwani</option>
#                                       <option value="15253">Solan</option>
#                                       <option value="20805">Solapur</option>
#                                       <option value="20816">Sonepat</option>
#                                       <option value="14847">Srinagar</option>
#                                       <option value="43431">Sriperumbudur</option>
#                                       <option value="15230">Sundargarh</option>
#                                       <option value="20055">Sundergarh</option>
#                                       <option value="15364">Surat</option>
#                                       <option value="14705">Thiru'puram</option>
#                                       <option value="19810">Thiruvananthapuram</option>
#                                       <option value="15123">Thoothukudi</option>
#                                       <option value="14912">Thrissur</option>
#                                       <option value="16628">Tinsukia</option>
#                                       <option value="14874">Tiruchirapalli</option>
#                                       <option value="41417">Tiruchirappalli</option>
#                                       <option value="41943">Tirupathi</option>
#                                       <option value="14978">Tirupati</option>
#                                       <option value="43769">Tirupur</option>
#                                       <option value="19413">Toansa</option>
#                                       <option value="43033">Trivandrum</option>
#                                       <option value="15369">Udaipur</option>
#                                       <option value="15361">Udham Singh Nagar</option>
#                                       <option value="15926">Una</option>
#                                       <option value="14449">Vadodara</option>
#                                       <option value="41657">Vallabh Vidyanagar</option>
#                                       <option value="15398">Valsad</option>
#                                       <option value="14646">Vapi</option>
#                                       <option value="15060">Varanasi</option>
#                                       <option value="41772">Vellore</option>
#                                       <option value="14559">Veraval</option>
#                                       <option value="41477">Visakhapatnam</option>
#                                       <option value="15458">Vishakapatnam</option>
#                                       <option value="18064">Vishakhapatam</option>
#                                       <option value="19566">West Godavari</option>
#                                       <option value="15003">Yamuna Nagar</option>
#                                       <option value="19501">Yavatmal</option>
#                                       <option value="14839">Zuarinagar</option>
#                                   </select>
#                 <i aria-hidden="true" class="fa fa-chevron-down"></i>
#               </div>
#             </div>
#
#     </form>
#               <div class="button-section-bottom">
#             <button class="black-button" onclick="resetAll()">Reset</button>
#             <button class="black-button" onclick="applyFilter()">Apply</button>
#           </div>
#
#   </div>
#
#   <div class="company-search-container company-search-container-mobile" id="company-search-mobile">
#     <div class="popup-header">
#       <span class="filter-header">SEARCH</span>
#       <span class="close-button" onclick="closeModalSearch()">×</span>
#     </div>
#     <div class="search-bar-body">
#       <div class="search-box search-box-mobile">
#     <form action="javascript:applyFilter()" class="search-form" id="search_comp_form_mobile" method="GET">
#         <div class="form-el">
#             <input class="search-text-input" id="company-search-input-mobile" name="search" placeholder="Search Company" type="text"/>
#             <button class="button-holder" onclick="applyFilter();" type="submit">
#                 <i class="fa fa-search"></i>
#             </button>
#         </div>
#     </form>
# </div>
#
#     </div>
#               <div class="button-section-bottom">
#             <button class="black-button" onclick="resetAll()">Reset</button>
#             <button class="black-button" onclick="applyFilter()">Apply</button>
#           </div>
#
#   </div>
#   <script>
#     function resetAll(){
#       $('#filter-industry-dropdown option:eq(0)').prop('selected', 'selected');
#       $('#sort-by-dropdown option:eq(0)').prop('selected', 'selected');
#       $('#filter-city-dropdown option:eq(0)').prop('selected', 'selected');
#     }
#     var currentMode = '';
#     var currentDevice = 'desktop';
#     function changePullDown() {
#       $("#mobile-filter-list").slideToggle();
#     }
#     function openFilter() {
#       $("#filter-dropdown-mobile").show();
#       currentMode = 'filter';
#       currentDevice = 'mobile';
#     }
#     function closeModal() {
#       $("#filter-dropdown-mobile").hide();
#       currentMode = '';
#     }
#     function openSearchMobile() {
#       $("#company-search-mobile").show();
#       currentMode = 'search';
#       currentDevice = 'mobile';
#     }
#     function closeModalSearch() {
#       $("#company-search-mobile").hide();
#       currentMode = '';
#     }
#     function toggleDektopFilter() {
#       $("#search-button-desktop").removeClass("white-button");
#       $("#filter-button-desktop").toggleClass("white-button");
#       $(".common-filter:not('#filter-dropdown-desktop')").hide();
#       if($('#filter-dropdown-desktop').css('display') == 'none')
#       {
#         $("#filter-dropdown-desktop").show();
#       } else {
#         $("#filter-dropdown-desktop").hide();
#         $("#filter-companies-desktop").show();
#       }
#       if($("#filter-button-desktop").hasClass('white-button')) {
#
#         currentMode = 'filter';
#       }
#     }
#     function toggleDesktopSearch() {
#
#       $("#filter-button-desktop").removeClass("white-button");
#       $("#search-button-desktop").toggleClass("white-button");
#       $(".common-filter:not('#search-bar-desktop')").hide();
#       if($('#search-bar-desktop').css('display') == 'none')
#       {
#         $("#search-bar-desktop").show();
#       } else {
#         $("#search-bar-desktop").hide();
#         $("#filter-companies-desktop").show();
#       }
#       if($("#search-button-desktop").hasClass('white-button')) {
#
#         currentMode = 'search';
#       }
#     }
#     function scrollToCompany(companySlug) {
#
#
#         if($("#"+CSS.escape(companySlug)).get(0)){
#         var scrollVar = parseInt($('#'+CSS.escape(companySlug)).offset().top) - $('.header').height() - 60;
#         $('html, body').animate({ scrollTop: scrollVar }, 'slow');
#       } else {
#
#         if(window.location.search) {
#           window.location.href = companySlug + window.location.search;
#         } else {
#           window.location.href = companySlug;
#         }
#       }
#     }
#
#     function applyFilter() {
#
#       if(currentMode == 'search') {
#         var searchParam = "";
#         var currentYear = 2019;
#         if (currentDevice === "desktop") {
#           searchParam = $("#search_comp_form_filter").find('input[name="search"]').val();
#         } else {
#           searchParam = $("#search_comp_form_mobile").find("#company-search-input-mobile").val();
#         }
#
#         if (searchParam.trim().length > 0) {
#             location.href = "/"+"fortune-500"+"/company-list/?mode=search&query="+searchParam+"&year="+currentYear;
#         }
#       }
#
#       if(currentMode == 'filter') {
#         if(currentDevice == 'desktop') {
#           var sortBy = $("#filter-form-desktop #sort-by-dropdown").val();
#           var filterIndustry = $("#filter-form-desktop #filter-industry-dropdown").val();
#           var filterCity = $("#filter-form-desktop #filter-city-dropdown").val();
#         } else if(currentDevice == 'mobile') {
#
#           var sortBy = $("#filter-form-mobile #sort-by-dropdown").val();
#           var filterIndustry = $("#filter-form-mobile #filter-industry-dropdown").val();
#           var filterCity = $("#filter-form-mobile #filter-city-dropdown").val();
#         }
#
#         var currentYear = 2019;
#
#         var url = "/"+"fortune-500"+"/company-list/?mode=filter&year="+currentYear;
#         if(filterCity != '' || filterIndustry != '') {
#           var url = "/"+"fortune-500"+"/company-list/?mode=filter&year="+currentYear;
#           if(filterCity) {
#             url = url + "&city=" + filterCity;
#           }
#
#           if(filterIndustry) {
#             url = url + "&industry=" + filterIndustry;
#           }
#         }
#         if(sortBy) {
#           url = url + "&" + sortBy;
#         }
#
#         location.href = url;
#       }
#     }
#
#     function resetAll() {
#       location.href = "/" + "fortune-500" + "/company-list?year=" + "2019";
#     }
#   </script>
# <!-- /1088475/FT_Desk_1x1 -->
# <div id="div-gpt-ad-1501150058174-4">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-4'); });
# </script>
# </div>
# <!-- /1088475/FT_Mob_1x1 -->
# <div id="div-gpt-ad-1501150058174-8">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058174-8'); });
# </script>
# </div>      </div>
#     </main>
#     <div class="story-go-to-top" onclick="goUp()">
#       <div class="fa fa-angle-up fa-6"></div>
#     </div>
#
#     <div class="cf"></div>
#
#           <footer class="page-footer">
#   <div class="container">
#     <div class="bottom-stickey show-on-mobile" id="div-gpt-ad-1501150058178-9">
#       <script>
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1501150058178-9'); });
#       </script>
#     </div>
#     <div class="footer-block">
#       <div class="footer-link">
#
# <ul class="menu-list">
#   <li class="menu-item hamburger-item">
#           <form action="/search" class="search-form" method="GET">
#   <div class="form-el">
#     <input class="search-text-input" id="js-hamburger-search-input" name="q" placeholder="Search" type="text"/>
#     <button class="button-holder">
#       <i class="fa fa-search"></i>
#     </button>
#   </div>
# </form>
#       </li>
#
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/contact-us">Contact Us</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="https://www.fortuneindia.com/core-values">Vision &amp; Core Values</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/terms-of-use">Terms of Use</a>
#     </li>
#               <li class="menu-item footer-item">
#       <a class="menu-anchor" href="/privacy-policy">Privacy &amp; Cookie Policy</a>
#     </li>
#
#
#     <li class="menu-item hamburger-item">
#     <div class="menu-anchor section-anchor social-media" title="Social share">
#       <ul>
#   <li><a class="social-icon" href="https://twitter.com/FortuneIndia" target="_blank"> <i class="fa fa-twitter bgm"></i></a></li>
#   <li><a class="social-icon" href="https://www.facebook.com/fortuneind/" target="_blank"> <i class="fa fa-facebook"></i></a></li>
#   <li><a class="social-icon" href="https://plus.google.com/100287022162827136313" target="_blank"> <i class="fa fa-google-plus"></i></a></li>
#   <li><a class="social-icon" href="mailto:digital@fortuneindia.com" target="_blank"> <i class="fa fa-envelope"></i></a></li>
#   <li><a class="social-icon" href="https://www.linkedin.com/company/fortune-india" target="_blank"> <i class="fa fa-linkedin"></i></a></li>
#   <li><a class="social-icon" href="https://www.instagram.com/fortune.india/" target="_blank"> <i class="fa fa-instagram"></i></a></li>
#   <li><a class="social-icon" href="https://www.youtube.com/channel/UC-RxD9CCCAQJYZLU6VbwKHw" target="_blank"> <i class="fa fa-youtube-play"></i></a></li>
# </ul>
#     </div>
#   </li>
#
# </ul>
#
#       </div>
#     </div>
#     <div class="h-row">
#       <hr/>
#     </div>
#     <div class="copyright-bottom">
#       <div class="copyright">
#                 ©2021 Business Media Private Limited. All rights reserved.
#       </div>
#       <div class="quintype-powered">
#         <a href="http://www.quintype.com" rel="nofollow" target="_blank" title="Quintype">Powered by Quintype</a>
#       </div>
#     </div>
#     <div class="cf"></div>
#   </div>
# </footer>
#       </div>
#   <script type="text/javascript">
#     var qtConfig = {
#       "image-cdn": "https://images.assettype.com",
#       "polltype-host": "https://api.polltype.com",
#       "mailchimp-config": {
#         mailchimp_key: "",
#         mailchimp_list_id: "",
#         mailchimp_url: ""
#       },
#     };
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#   <script src="https://fea.assettype.com/abp/assets/application-268343de85.js" type="text/javascript"></script>
#   <script type="text/javascript">
#     app.initQtReady();
#
#     function goUp() {
#       app.storyReadMore.scrollToTop();
#     }
#
#     $(document).ready(function(){
#               window.dataLayer = window.dataLayer || [];
#         window.dataLayer.push({
#           'pageType':'fortune500',
#           'Sectionname':'',
#           'cmsContentId': '',
#           'contentUrl': '',
#           'Title': '',
#           'Alternate Title': '',
#           'authorname': '',
#           'tagname': '',
#           'publishdate': '',
#           'publishtime': ''
#         });
#           });
#   </script>
#
#
#
# </body></html>

# %%
with pd.ExcelWriter(r'C:\Users\Sreeram\Downloads\Fortune500 (%s) Companies Details.xlsx'%(com_search1)) as writer:
    #Companies.to_excel(writer,sheet_name='Company_Details')
    Comp_Revenue.to_excel(writer,sheet_name=f'{com_search1}')
    fortune_500_hist.to_excel(writer,sheet_name=f'{com_search1}Company_History')
    prof_ratio.to_excel(writer,sheet_name=f'{com_search1}Profit_Ratios')
